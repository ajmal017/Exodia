# %%
import requests
import json

# %%
NAME = 'jfin'
API_KEY = '43a561d429534e228200b75178d4f92b'
url = f"http://newsapi.org/v2/everything?q={NAME}&from=2020-06-20&to=2020-06-30&sortBy=popularity&apiKey={API_KEY}"

# %%
jj = requests.get(url).json()

# %%
len(jj['articles'])
# Out:
# 5

# %%
jj
# Out:
# {'status': 'ok',
#  'totalResults': 5,
#  'articles': [{'source': {'id': None, 'name': 'Sina.com.cn'},
#    'author': '爱投顾股票',
#    'title': '中国概念股周五收盘多数下跌瑞幸咖啡重挫54% - 新浪网',
#    'description': '<ol><li>中国概念股周五收盘多数下跌瑞幸咖啡重挫54%\xa0\xa0新浪网\r\n</li><li>已熔断四次瑞幸咖啡股价逼近历史新低- 最新消息\xa0\xa0cnBeta\r\n</li><li>瑞幸再收退市通知 陸正耀將為造假付巨額帳單\xa0\xa0大纪元\r\n</li><li>瑞幸咖啡撤回听证会请求6月29日停牌并退市\xa0\xa0新浪网\r\n</li><li>瑞幸咖啡撤回听证会请求6月29日停牌并退市- 最新消息\xa0\xa0cnBeta\r\n</li><li>在Google 新闻上查看完整报道</li></ol>',
#    'url': 'https://finance.sina.com.cn/roll/2020-06-27/doc-iircuyvk0598710.shtml',
#    'urlToImage': 'https://finance.sina.com.cn//n.sinaimg.cn/spider2020627/561/w360h1801/20200627/1fb5-ivmqpck1839456.jpg',
#    'publishedAt': '2020-06-26T21:39:39Z',
#    'content': '54% \r\n 627700(LK)62954%4%152%\r\n50074.702.42%3009.06259.802.59%9757.22730.202.84%25015.413.31%1.9%5002.86%\r\nADR12.69628.151.98% \r\n(BABA)2.90%0.98%(JD)1.42%(NTES)0.46%(BIDU)1.56%(XRS)0.59%0.35%0.39%0.6… [+296 chars]'},
# ...

# %%
jj['articles'][0]
# Out:
# {'source': {'id': 'engadget', 'name': 'Engadget'},
#  'author': 'Christine Fisher',
#  'title': 'Facebook will prioritize original reporting in its News Feed',
#  'description': 'In an effort to prioritize original reporting, Facebook is updating the way it ranks news stories in its News Feed. Beginning today, Facebook will use AI to analyze groups of articles on a given topic and prioritize the ones cited most often as the original s…',
#  'url': 'https://www.engadget.com/facebook-original-reporting-byline-news-feed-145236532.html',
#  'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2020-06%2F5f7ecbc0-badf-11ea-beff-e2b66e780cc3&client=amp-blogside-v2&signature=23b86584d8f1facaada2360127c557ce9bb2ce22',
#  'publishedAt': '2020-06-30T14:52:36Z',
# ...

# %%
print(json.dumps(jj, indent=4, sort_keys=True))
# Out:
# {
#     "articles": [
#         {
#             "author": "Christine Fisher",
#             "content": "Publishers probably won\u2019t see significant changes in traffic, either, Facebook says. For now, these changes only apply to stories written in English, but Facebook will expand the approach to other la\u2026 [+1054 chars]",
#             "description": "In an effort to prioritize original reporting, Facebook is updating the way it ranks news stories in its News Feed. Beginning today, Facebook will use AI to analyze groups of articles on a given topic and prioritize the ones cited most often as the original s\u2026",
#             "publishedAt": "2020-06-30T14:52:36Z",
#             "source": {
#                 "id": "engadget",
#                 "name": "Engadget"
#             },
#             "title": "Facebook will prioritize original reporting in its News Feed",
#             "url": "https://www.engadget.com/facebook-original-reporting-byline-news-feed-145236532.html",
# ...
