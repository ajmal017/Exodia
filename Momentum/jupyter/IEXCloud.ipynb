# %%
import pyEX as p

# %%
'https://pyex.readthedocs.io/en/latest/'
'https://iexcloud.io/docs/api/#advanced-stats'
'youtube.com/watch?v=M7Ge0zi0oS4&feature=youtu.be'
# Out:
# 'youtube.com/watch?v=M7Ge0zi0oS4&feature=youtu.be'

# %%
secret = 'sk_fae174660924464996b77d14209a973b'
public = 'pk_2f3691af11ad4df583c95f2a4d89d44a'
c = p.Client(api_token=secret, version='v1', api_limit=5)

# %%
p.ceoCompensation('aapl')
# Out:
# ---------------------------------------------------------------------------
# PyEXception                               Traceback (most recent call last)
# <ipython-input-9-3c01da43a104> in <module>
# ----> 1 p.ceoCompensation('aapl')
#
# ~/anaconda3/lib/python3.7/site-packages/temporalcache/expire.py in _wrapped_foo(*args, **kwargs)
#      77             kwargs = {k: frozendict(v) if isinstance(v, dict) else tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
#      78
# ---> 79             return foo(*args, **kwargs)
#      80         return _wrapped_foo
#      81     return _wrapper
#
# ~/anaconda3/lib/python3.7/site-packages/temporalcache/persistent_lru_cache.py in wrapper(*args, **kwds)
#     202                         hits += 1
#     203                         return result
# --> 204                 result = user_function(*args, **kwds)
#     205                 with lock:
#     206                     if key in cache:
#
# ...

# %%
import requests

# %%
symbol = 'hexo'
url = f'https://cloud.iexapis.com/v1/stock/{symbol}/advanced-stats?token={secret}'

# %%
html = requests.get(url)

# %%
html.json()
# Out:
# {'week52change': -0.8610039999999999,
#  'week52high': 5.38,
#  'week52low': 0.3455,
#  'marketcap': 294197040,
#  'employees': 1260,
#  'day200MovingAvg': 1.5234,
#  'day50MovingAvg': 0.6759,
#  'float': 399743906,
#  'avg10Volume': 11328444.8,
#  'avg30Volume': 27308063.67,
#  'ttmEPS': -1.2226,
#  'ttmDividendRate': None,
#  'companyName': 'HEXO Corp.',
#  'sharesOutstanding': 408607000,
#  'maxChangePercent': -0.4966,
#  'year5ChangePercent': -0.4966,
#  'year2ChangePercent': -0.8082,
#  'year1ChangePercent': -0.863327,
#  'ytdChangePercent': -0.559146,
#  'month6ChangePercent': -0.53949,
#  'month3ChangePercent': 0.071429,
#  'month1ChangePercent': 0.046916,
#  'day30ChangePercent': 0.394407,
#  'day5ChangePercent': 0.044798,
#  'nextDividendDate': None,
#  'dividendYield': None,
#  'nextEarningsDate': None,
#  'exDividendDate': None,
#  'peRatio': -0.59,
#  'beta': 0.9691319262968119,
#  'totalCash': 123257054,
#  'currentDebt': 2373682,
#  'revenue': 35924537,
# ...

# %%
c.chartDF('AAPL')
# Out:
#             change  changeOverTime  changePercent   close    high   label  \
# date
# 2020-06-03    0.00        0.000000         0.0000  325.12  326.20   Jun 3
# 2020-06-04   -2.80       -0.008612        -0.8612  322.32  325.62   Jun 4
# 2020-06-05    9.18        0.019624         2.8481  331.50  331.75   Jun 5
# 2020-06-08    1.96        0.025652         0.5913  333.46  333.60   Jun 8
# 2020-06-09   10.53        0.058040         3.1578  343.99  345.61   Jun 9
# 2020-06-10    8.85        0.085261         2.5727  352.84  354.77  Jun 10
# 2020-06-11  -16.94        0.033157        -4.8010  335.90  351.06  Jun 11
# 2020-06-12    2.90        0.042077         0.8634  338.80  347.80  Jun 12
# 2020-06-15    4.19        0.054964         1.2367  342.99  345.68  Jun 15
# 2020-06-16    9.09        0.082923         2.6502  352.08  353.20  Jun 16
# 2020-06-17   -0.49        0.081416        -0.1392  351.59  355.40  Jun 17
# 2020-06-18    0.14        0.081847         0.0398  351.73  353.45  Jun 18
# ...

# %%
c.ceoCompensation('AAPL')
# Out:
# ---------------------------------------------------------------------------
# PyEXception                               Traceback (most recent call last)
# <ipython-input-22-d61ed4cb62dc> in <module>
# ----> 1 c.ceoCompensation('AAPL')
#
# ~/anaconda3/lib/python3.7/site-packages/pyEX/client.py in bind(self, *args, **kwargs)
#     658         if not meth:
#     659             raise PyEXception('Must provide method!')
# --> 660         return meth(token=self._token, version=self._version, *args, **kwargs)
#     661
#     662     def account(self):
#
# ~/anaconda3/lib/python3.7/site-packages/temporalcache/expire.py in _wrapped_foo(*args, **kwargs)
#      77             kwargs = {k: frozendict(v) if isinstance(v, dict) else tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
#      78
# ---> 79             return foo(*args, **kwargs)
#      80         return _wrapped_foo
#      81     return _wrapper
#
# ...

# %%
symbol = 'HEXO'
p.chart(symbol, timeframe='1d', date=None, token=secret, version='v1', filter='')
# Out:
# [{'date': '2020-06-03',
#   'open': 0.6875,
#   'close': 0.6906,
#   'high': 0.6964,
#   'low': 0.658,
#   'volume': 31071332,
#   'uOpen': 0.6875,
#   'uClose': 0.6906,
#   'uHigh': 0.6964,
#   'uLow': 0.658,
#   'uVolume': 31071332,
#   'change': 0,
#   'changePercent': 0,
#   'label': 'Jun 3',
#   'changeOverTime': 0},
#  {'date': '2020-06-04',
#   'open': 0.7,
#   'close': 0.73,
#   'high': 0.77,
#   'low': 0.7,
#   'volume': 39214551,
#   'uOpen': 0.7,
#   'uClose': 0.73,
#   'uHigh': 0.77,
#   'uLow': 0.7,
#   'uVolume': 39214551,
#   'change': 0.0394,
#   'changePercent': 5.7052,
#   'label': 'Jun 4',
#   'changeOverTime': 0.057052},
#  {'date': '2020-06-05',
#   'open': 0.765,
#   'close': 0.8074,
#   'high': 0.83,
#   'low': 0.7333,
#   'volume': 28910125,
#   'uOpen': 0.765,
#   'uClose': 0.8074,
#   'uHigh': 0.83,
#   'uLow': 0.7333,
#   'uVolume': 28910125,
#   'change': 0.0774,
#   'changePercent': 10.6027,
#   'label': 'Jun 5',
#   'changeOverTime': 0.169128},
# ...

# %%
from datetime import datetime

start = 1572613424
end = 1572613424
startD = datetime.fromtimestamp(start)
endD = datetime.fromtimestamp(end)

print("Start: ", startD)
print("End: ", endD)
# Out:
# Start:  2019-11-01 09:03:44
# End:  2019-11-01 09:03:44

# %%
symbol = 'TSLA'
p.analystRecommendations(symbol, token=secret, version='v1', filter='')
# Out:
# [{'ratingBuy': 8,
#   'ratingOverweight': 1,
#   'ratingHold': 11,
#   'ratingUnderweight': 3,
#   'ratingSell': 9,
#   'ratingNone': 2,
#   'ratingScaleMark': 2.0625,
#   'consensusStartDate': 1593820800000,
#   'consensusEndDate': None,
#   'corporateActionsAppliedDate': None},
#  {'ratingBuy': 8,
#   'ratingOverweight': 1,
#   'ratingHold': 12,
#   'ratingUnderweight': 3,
#   'ratingSell': 9,
#   'ratingNone': 2,
#   'ratingScaleMark': 2.060606,
#   'consensusStartDate': 1591920000000,
#   'consensusEndDate': 1593734400000,
#   'corporateActionsAppliedDate': None},
#  {'ratingBuy': 8,
#   'ratingOverweight': 1,
#   'ratingHold': 13,
#   'ratingUnderweight': 3,
#   'ratingSell': 8,
#   'ratingNone': 2,
#   'ratingScaleMark': 2.030303,
#   'consensusStartDate': 1591747200000,
#   'consensusEndDate': 1591833600000,
#   'corporateActionsAppliedDate': None},
#  {'ratingBuy': 9,
#   'ratingOverweight': 1,
#   'ratingHold': 12,
#   'ratingUnderweight': 3,
#   'ratingSell': 8,
# ...

# %%
symbol = 'HEXO'
p.balanceSheet('ACDVF', token=secret, version='v1')
# Out:
# {'symbol': 'ACDVF',
#  'balancesheet': [{'reportDate': '2020-03-31',
#    'fiscalDate': '2020-03-31',
#    'currency': 'USD',
#    'currentCash': 1890610180,
#    'shortTermInvestments': 2487090315,
#    'receivables': 398355991,
#    'inventory': 149646960,
#    'otherCurrentAssets': 187585625,
#    'currentAssets': 5113289072,
#    'longTermInvestments': None,
#    'propertyPlantEquipment': 9043453824,
#    'goodwill': 2299504690,
#    'intangibleAssets': 739803984,
#    'otherAssets': 2685917030,
#    'totalAssets': 19907963607,
#    'accountsPayable': 1587803422,
#    'currentLongTermDebt': 732778305,
#    'otherCurrentLiabilities': 2195524643,
#    'totalCurrentLiabilities': 4516106369,
#    'longTermDebt': 6779780096,
#    'otherLiabilities': 2809568970,
#    'minorityInterest': 0,
#    'totalLiabilities': 16914321846,
#    'commonStock': 260933172,
#    'retainedEarnings': 2421751502,
#    'treasuryStock': None,
#    'capitalSurplus': 61123406,
# ...

# %%
p.balanceSheet('AAPL', token=secret, version='v1')
# Out:
# {'symbol': 'AAPL',
#  'balancesheet': [{'reportDate': '2020-03-31',
#    'fiscalDate': '2020-03-28',
#    'currency': 'USD',
#    'currentCash': 29955000000,
#    'shortTermInvestments': 65173000000,
#    'receivables': 15722000000,
#    'inventory': 3334000000,
#    'otherCurrentAssets': 14614000000,
#    'currentAssets': 143753000000,
#    'longTermInvestments': 100591000000,
#    'propertyPlantEquipment': 43986000000,
#    'goodwill': None,
#    'intangibleAssets': None,
#    'otherAssets': 32070000000,
#    'totalAssets': 320400000000,
#    'accountsPayable': 32421000000,
#    'currentLongTermDebt': 10411000000,
#    'otherCurrentLiabilities': 42048000000,
#    'totalCurrentLiabilities': 96094000000,
#    'longTermDebt': 97136000000,
#    'otherLiabilities': 20557000000,
#    'minorityInterest': 0,
#    'totalLiabilities': 241975000000,
#    'commonStock': 4323987000,
#    'retainedEarnings': 33182000000,
#    'treasuryStock': None,
#    'capitalSurplus': None,
# ...

# %%
p.balanceSheet('MSFT', token=secret, version='v1')
# Out:
# {'symbol': 'MSFT',
#  'balancesheet': [{'reportDate': '2020-03-31',
#    'fiscalDate': '2020-03-31',
#    'currency': 'USD',
#    'currentCash': 11710000000,
#    'shortTermInvestments': 125916000000,
#    'receivables': 22699000000,
#    'inventory': 1644000000,
#    'otherCurrentAssets': 8536000000,
#    'currentAssets': 170505000000,
#    'longTermInvestments': 2660000000,
#    'propertyPlantEquipment': 49669000000,
#    'goodwill': 42064000000,
#    'intangibleAssets': 6855000000,
#    'otherAssets': 11196000000,
#    'totalAssets': 285449000000,
#    'accountsPayable': 9246000000,
#    'currentLongTermDebt': 4218000000,
#    'otherCurrentLiabilities': 40390000000,
#    'totalCurrentLiabilities': 58707000000,
#    'longTermDebt': 78250000000,
#    'otherLiabilities': 33806000000,
#    'minorityInterest': 0,
#    'totalLiabilities': 170948000000,
#    'commonStock': 7590000000,
#    'retainedEarnings': 32012000000,
#    'treasuryStock': None,
#    'capitalSurplus': None,
# ...

# %%
p.cashFlow(symbol='AAPL', token=secret, version='v1', filter='')
# Out:
# {'symbol': 'AAPL',
#  'cashflow': [{'reportDate': '2020-03-31',
#    'fiscalDate': '2020-03-28',
#    'currency': 'USD',
#    'netIncome': 11249000000,
#    'depreciation': 2786000000,
#    'changesInReceivables': 5248000000,
#    'changesInInventories': 727000000,
#    'cashChange': 1384000000,
#    'cashFlow': 13311000000,
#    'capitalExpenditures': -1853000000,
#    'investments': 11338000000,
#    'investingActivityOther': -296000000,
#    'totalInvestingCashFlows': 9013000000,
#    'dividendsPaid': -3375000000,
#    'netBorrowings': 803000000,
#    'otherFinancingCashFlows': -222000000,
#    'cashFlowFinancing': -20940000000,
#    'exchangeRateEffect': None}]}

# %%
p.cashFlow(symbol='ACDVF', token=secret, version='v1', filter='')
# Out:
# {'symbol': 'ACDVF',
#  'cashflow': [{'reportDate': '2020-03-31',
#    'fiscalDate': '2020-03-31',
#    'currency': 'USD',
#    'netIncome': -779899376,
#    'depreciation': 362069586,
#    'changesInReceivables': 315736933,
#    'changesInInventories': None,
#    'cashChange': 370247750,
#    'cashFlow': -14869388,
#    'capitalExpenditures': -277314077,
#    'investments': 303335506,
#    'investingActivityOther': None,
#    'totalInvestingCashFlows': 50555918,
#    'dividendsPaid': None,
#    'netBorrowings': 502585299,
#    'otherFinancingCashFlows': None,
#    'cashFlowFinancing': 287722649,
#    'exchangeRateEffect': 46838571}]}

# %%
p.incomeStatement(symbol='ACDVF', token=secret, version='v1', filter='')
# Out:
# {'symbol': 'ACDVF',
#  'income': [{'reportDate': '2020-03-31',
#    'fiscalDate': '2020-03-31',
#    'currency': 'USD',
#    'totalRevenue': 2767193020,
#    'costOfRevenue': 2569430166,
#    'grossProfit': 197762854,
#    'researchAndDevelopment': None,
#    'sellingGeneralAndAdmin': None,
#    'operatingExpense': 3076476280,
#    'operatingIncome': -321922240,
#    'otherIncomeExpenseNet': -626744685,
#    'ebit': -321922240,
#    'interestIncome': 89959795,
#    'pretaxIncome': -948666925,
#    'incomeTax': -168767548,
#    'minorityInterest': 0,
#    'netIncome': -779899376,
#    'netIncomeBasic': -779899376}]}

# %%
948666925-168767548
# Out:
# 779899377

# %%
symbol = 'JFIN'
p.bonusIssue(symbol, token=secret, version='v1')
# Out:
# []

# %%
symbol = 'AAPL'
p.book('NXGWF', token=secret, version='v1')
# Out:
# {'quote': {'symbol': 'NXGWF',
#   'companyName': 'Next Green Wave Holdings, Inc.',
#   'primaryExchange': 'US OTC',
#   'calculationPrice': 'previousclose',
#   'open': None,
#   'openTime': None,
#   'openSource': 'official',
#   'close': None,
#   'closeTime': None,
#   'closeSource': 'official',
#   'high': 0.125,
#   'highTime': 1594234275810,
#   'highSource': '15 minute delayed price',
#   'low': 0.11,
#   'lowTime': 1594218455236,
#   'lowSource': '15 minute delayed price',
#   'latestPrice': 0.1104,
#   'latestSource': 'Previous close',
#   'latestTime': 'July 7, 2020',
#   'latestUpdate': 1594094400000,
#   'latestVolume': 0,
#   'iexRealtimePrice': None,
#   'iexRealtimeSize': None,
#   'iexLastUpdated': None,
#   'delayedPrice': None,
#   'delayedPriceTime': None,
#   'oddLotDelayedPrice': None,
#   'oddLotDelayedPriceTime': None,
#   'extendedPrice': None,
#   'extendedChange': None,
#   'extendedChangePercent': None,
#   'extendedPriceTime': None,
# ...

# %%
p.brain30DaySentiment(key='aapl', range=None, calendar=False, limit=1, dateField=None, from_='2020-06-22', to_='2020-06-29', on='2020-06-28', last=10, first=10, token=secret, version='v1', filter='')
# Out:
# ---------------------------------------------------------------------------
# PyEXception                               Traceback (most recent call last)
# <ipython-input-47-acac5b33e9ff> in <module>
# ----> 1 p.brain30DaySentiment(key='aapl', range=None, calendar=False, limit=1, dateField=None, from_='2020-06-22', to_='2020-06-29', on='2020-06-28', last=10, first=10, token=secret, version='v1', filter='')
#
# ~/anaconda3/lib/python3.7/site-packages/pyEX/premium/brain/__init__.py in brain30DaySentiment(symbol, **kwargs)
#      26     https://iexcloud.io/docs/api/#brain-companys-30-day-sentiment-indicator
#      27     '''
# ---> 28     return _base(id='PREMIUM_BRAIN_SENTIMENT_30_DAYS', symbol=symbol, **kwargs)
#      29
#      30
#
# ~/anaconda3/lib/python3.7/site-packages/temporalcache/expire.py in _wrapped_foo(*args, **kwargs)
#      77             kwargs = {k: frozendict(v) if isinstance(v, dict) else tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
#      78
# ...

# %%
#1
symbol = 'aapl'
p.company(symbol='NXGWF', token=secret, version='v1', filter='')
# Out:
# {'symbol': 'NXGWF',
#  'companyName': 'Next Green Wave Holdings, Inc.',
#  'exchange': 'US OTC',
#  'industry': 'Financial Conglomerates',
#  'website': 'http://www.nextgreenwave.com',
#  'description': 'Next Green Wave Holdings, Inc. engages in the production and supply of medical cannabis products through its subsidiary, Next Green Wave, LLC. It also provides corporate services including accounting, human resources, finance, corporate development, sales, and marketing. The company was founded by Paul Chow & Ryan Lange on July 6, 2011 and is headquartered in Vancouver, Canada.',
#  'CEO': 'Michael Jennings',
#  'securityName': 'Next Green Wave Holdings, Inc.',
#  'issueType': 'cs',
#  'sector': 'Finance',
#  'primarySicCode': 6799,
#  'employees': None,
#  'tags': ['Financial Conglomerates', 'Finance'],
#  'address': '1055 West Hastings Street',
#  'address2': None,
#  'state': 'BC',
#  'city': 'Vancouver',
#  'zip': 'V6E',
#  'country': 'CA',
#  'phone': '1.604.609.6180'}

# %%
symbol = 'aapl'
p.chart(symbol=symbol, timeframe='1mm', token=secret, version='v1', filter='')
# Out:
# [{'date': '2020-06-05',
#   'minute': '09:30',
#   'label': '09:30',
#   'open': 323.38,
#   'high': 327.95,
#   'low': 323.38,
#   'close': 326.805,
#   'average': 326.399291,
#   'volume': 28555,
#   'notional': 9320333.079999998,
#   'numberOfTrades': 245,
#   'marketOpen': 323.35,
#   'marketHigh': 328,
#   'marketLow': 323.23,
#   'marketClose': 326.79,
#   'marketAverage': 326.109124,
#   'marketVolume': 4095600,
#   'marketNotional': 1335612710.4515002,
#   'marketNumberOfTrades': 20267},
#  {'date': '2020-06-05',
#   'minute': '10:00',
#   'label': '10:00',
#   'open': 326.82,
#   'high': 326.97,
#   'low': 325.86,
#   'close': 326.65,
#   'average': 326.452149,
#   'volume': 11533,
#   'notional': 3764972.6849999996,
#   'numberOfTrades': 129,
#   'marketOpen': 326.82,
#   'marketHigh': 326.97,
#   'marketLow': 325.72,
#   'marketClose': 326.64,
#   'marketAverage': 326.407631,
#   'marketVolume': 1672117,
#   'marketNotional': 545791797.2219002,
# ...

# %%
symbol = 'aapl'
p.corporateActions(symbol=symbol, token=secret, version='v1', filter='')
# Out:
# /home/lukepiette/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecatedWarning: corporateActions is deprecated. Deprecated: IEX Cloud status unkown
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-cbe80249f33a> in <module>
#       1 symbol = 'aapl'
# ----> 2 p.corporateActions(symbol=symbol, token=secret, version='v1', filter='')
#
# ~/anaconda3/lib/python3.7/site-packages/deprecation.py in _inner(*args, **kwargs)
#     258                               stacklevel=2)
#     259
# --> 260             return function(*args, **kwargs)
#     261         return _inner
#     262     return _function_wrapper
#
# TypeError: corporateActions() got an unexpected keyword argument 'symbol'

# %%
symbol = 'aapl'
p.deep(symbol=symbol, token=secret, version='v1')
# Out:
# {'symbol': 'AAPL',
#  'marketPercent': 0,
#  'volume': 0,
#  'lastSalePrice': 0,
#  'lastSaleSize': 0,
#  'lastSaleTime': 0,
#  'lastUpdated': 0,
#  'bids': [],
#  'asks': [],
#  'systemEvent': {},
#  'tradeBreaks': []}

# %%
symbol = 'aapl'
p.delayedQuote(symbol=symbol, token=secret, version='v1')
# Out:
# {}

# %%
# 75,000
symbol = 'aapl'
p.distribution(refid='', symbol=symbol, token=secret, version='v1')
# Out:
# []

# %%
symbol = 'aapl'
p.dividends(symbol=symbol, token=secret, version='v1')
# Out:
# [{'exDate': '2020-05-08',
#   'paymentDate': '2020-05-14',
#   'recordDate': '2020-05-11',
#   'declaredDate': '2020-04-30',
#   'amount': '0.82',
#   'flag': 'Cash',
#   'currency': 'USD',
#   'description': 'Ordinary Shares',
#   'frequency': 'quarterly',
#   'date': '2020-07-05'},
#  {'exDate': '2020-02-07',
#   'paymentDate': '2020-02-13',
#   'recordDate': '2020-02-10',
#   'declaredDate': '2020-01-28',
#   'amount': '0.77',
#   'flag': 'Cash',
#   'currency': 'USD',
#   'description': 'Ordinary Shares',
#   'frequency': 'quarterly',
#   'date': '2020-07-05'}]

# %%
symbol = 'aapl'
p.earnings(symbol=symbol, token=secret, version='v1')
# Out:
# {'symbol': 'AAPL',
#  'earnings': [{'actualEPS': 2.55,
#    'consensusEPS': 2.25,
#    'announceTime': 'AMC',
#    'numberOfEstimates': 32,
#    'EPSSurpriseDollar': 0.3,
#    'EPSReportDate': '2020-04-30',
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'yearAgo': 2.46,
#    'yearAgoChangePercent': 0.0366,
#    'currency': 'USD'}]}

# %%
# 10,000
symbol = 'aapl'
p.estimates(symbol=symbol, token=secret, version='v1')
# Out:
# {'symbol': 'AAPL',
#  'estimates': [{'consensusEPS': 2,
#    'announceTime': 'AMC',
#    'numberOfEstimates': 35,
#    'reportDate': '2020-07-30',
#    'fiscalPeriod': 'Q2 2020',
#    'fiscalEndDate': '2020-06-30',
#    'currency': 'USD'}]}

# %%
p.exchanges(token=secret, version='v1')
# Out:
# [{'mic': 'ARCX',
#   'name': 'NYSE Arca',
#   'longName': 'NYSE ARCA',
#   'tapeId': 'P',
#   'oatsId': 'XP',
#   'refId': 'PSE',
#   'type': 'equities'},
#  {'mic': 'EDGX',
#   'name': 'Cboe EDGX',
#   'longName': 'Cboe EDGX US Equities Exchange',
#   'tapeId': 'K',
#   'oatsId': 'XK',
#   'refId': 'EDGX',
#   'type': 'equities'},
#  {'mic': 'BATS',
#   'name': 'Cboe BZX',
#   'longName': 'Cboe BZX US Equities Exchange',
#   'tapeId': 'Z',
#   'oatsId': 'XZ',
#   'refId': 'BATS',
#   'type': 'equities'},
#  {'mic': 'BATY',
#   'name': 'Cboe BYX',
#   'longName': 'Cboe BYX US Equities Exchange',
#   'tapeId': 'Y',
#   'oatsId': 'XY',
#   'refId': 'BATY',
#   'type': 'equities'},
#  {'mic': 'EDGA',
#   'name': 'Cboe EDGA',
#   'longName': 'Cboe EDGA US Equities Exchange',
#   'tapeId': 'J',
#   'oatsId': 'XJ',
#   'refId': 'EDGA',
#   'type': 'equities'},
#  {'mic': 'IEXG',
#   'name': 'IEX',
#   'longName': 'Investors Exchange',
#   'tapeId': 'V',
#   'oatsId': 'XV',
# ...

# %%
symbol = 'aapl'
p.financials(symbol=symbol, token=secret, version='v1')
# Out:
# {'symbol': 'AAPL',
#  'financials': [{'reportDate': '2020-03-31',
#    'fiscalDate': '2020-03-28',
#    'currency': 'USD',
#    'grossProfit': 22416000000,
#    'costOfRevenue': 35931000000,
#    'operatingRevenue': 58347000000,
#    'totalRevenue': 58347000000,
#    'operatingIncome': 12899000000,
#    'netIncome': 11249000000,
#    'researchAndDevelopment': 4565000000,
#    'operatingExpense': 45448000000,
#    'currentAssets': 143753000000,
#    'totalAssets': 320400000000,
#    'totalLiabilities': 241975000000,
#    'currentCash': 29955000000,
#    'currentDebt': 21625000000,
#    'shortTermDebt': 21625000000,
#    'longTermDebt': 97136000000,
#    'totalCash': 95128000000,
#    'totalDebt': 118761000000,
#    'shareholderEquity': 78425000000,
#    'cashChange': 1384000000,
#    'cashFlow': 13311000000}]}

# %%
p.iexSymbols(token=secret,version='v1')
# Out:
# [{'symbol': 'A', 'date': '2020-07-02', 'isEnabled': True},
#  {'symbol': 'AA', 'date': '2020-07-02', 'isEnabled': True},
#  {'symbol': 'AAAU', 'date': '2020-07-02', 'isEnabled': True},
#  {'symbol': 'AACG', 'date': '2020-07-02', 'isEnabled': True},
#  {'symbol': 'AADR', 'date': '2020-07-02', 'isEnabled': True},
#  {'symbol': 'AAL', 'date': '2020-07-02', 'isEnabled': True},
#  {'symbol': 'AAMC', 'date': '2020-07-02', 'isEnabled': True},
#  {'symbol': 'AAME', 'date': '2020-07-02', 'isEnabled': True},
#  {'symbol': 'AAN', 'date': '2020-07-02', 'isEnabled': True},
#  {'symbol': 'AAOI', 'date': '2020-07-02', 'isEnabled': True},
#  {'symbol': 'AAON', 'date': '2020-07-02', 'isEnabled': True},
#  {'symbol': 'AAP', 'date': '2020-07-02', 'isEnabled': True},
#  {'symbol': 'AAPL', 'date': '2020-07-02', 'isEnabled': True},
#  {'symbol': 'AAT', 'date': '2020-07-02', 'isEnabled': True},
#  {'symbol': 'AAU', 'date': '2020-07-02', 'isEnabled': True},
# ...

# %%
symbol = 'aapl'
p.fundOwnership(symbol=symbol, token=secret, version='v1')
# Out:
# [{'report_date': 1590883200000,
#   'entityProperName': 'Vanguard Total Stock Market Index Fund',
#   'adjHolding': 115333877,
#   'adjMv': 36669252853,
#   'reportedHolding': 115333877,
#   'reportedMv': 36669252853},
#  {'report_date': 1590883200000,
#   'entityProperName': 'Vanguard 500 Index Fund',
#   'adjHolding': 85290406,
#   'adjMv': 27117231684,
#   'reportedHolding': 85290406,
#   'reportedMv': 27117231684},
#  {'report_date': 1577750400000,
#   'entityProperName': 'Government Pension Fund - Global (the)',
#   'adjHolding': 45329151,
#   'adjMv': 13310905191,
#   'reportedHolding': 45329151,
#   'reportedMv': 13310905192},
#  {'report_date': 1593475200000,
#   'entityProperName': 'Spdr S&p 500 Etf',
#   'adjHolding': 43636194,
#   'adjMv': 15918483571,
#   'reportedHolding': 43636194,
#   'reportedMv': 15918483571},
#  {'report_date': 1593475200000,
#   'entityProperName': 'Invesco Qqq Trust',
#   'adjHolding': 37893614,
#   'adjMv': 13823590387,
# ...

# %%
symbol = 'HEXO'
p.fundOwnership(symbol=symbol, token=secret, version='v1')
# Out:
# [{'report_date': 1593475200000,
#   'entityProperName': 'Etfmg Alternative Harvest Etf',
#   'adjHolding': 21504757,
#   'adjMv': 15892015,
#   'reportedHolding': 21504757,
#   'reportedMv': 15883414},
#  {'report_date': 1561680000000,
#   'entityProperName': 'Ci First Asset Morningstar Us Value Index Etf',
#   'adjHolding': 13025903,
#   'adjMv': 69297804,
#   'reportedHolding': 13025903,
#   'reportedMv': 69297804},
#  {'report_date': 1577836800000,
#   'entityProperName': 'Horizons Medical Marijuana Life Sciences Etf',
#   'adjHolding': 5706710,
#   'adjMv': 7133388,
#   'reportedHolding': 5706710,
#   'reportedMv': 9109612},
#  {'report_date': 1561852800000,
#   'entityProperName': 'Manulife Dividend Income Plus Fund',
#   'adjHolding': 2529419,
#   'adjMv': 13456509,
#   'reportedHolding': 2529419,
#   'reportedMv': 13530515},
#  {'report_date': 1588204800000,
#   'entityProperName': 'Cref Stock Account',
#   'adjHolding': 944307,
#   'adjMv': 486318,
# ...

# %%
symbol = 'AAPL'
p.institutionalOwnership(symbol=symbol, token=secret, version='v1')
# Out:
# [{'reportDate': 1585612800000,
#   'entityProperName': 'Vanguard Group, Inc. (Subfiler)',
#   'adjHolding': 315934247,
#   'reportedHolding': 315934247,
#   'adjMv': 80338919670},
#  {'reportDate': 1585612800000,
#   'entityProperName': 'Berkshire Hathaway, Inc.',
#   'adjHolding': 245155566,
#   'reportedHolding': 245155566,
#   'adjMv': 62340608878},
#  {'reportDate': 1585612800000,
#   'entityProperName': 'State Street Corp.',
#   'adjHolding': 180558954,
#   'reportedHolding': 180558954,
#   'adjMv': 45914336413},
#  {'reportDate': 1585612800000,
#   'entityProperName': 'BlackRock Institutional Trust Co. NA',
#   'adjHolding': 100597132,
#   'reportedHolding': 100597132,
#   'adjMv': 25580844696},
#  {'reportDate': 1585612800000,
#   'entityProperName': 'BlackRock Fund Advisors',
#   'adjHolding': 86757716,
#   'reportedHolding': 86757716,
#   'adjMv': 22061619602},
#  {'reportDate': 1585612800000,
#   'entityProperName': 'Fidelity Management & Research Co. LLC',
# ...

# %%
symbol = 'HEXO'
p.insiderRoster(symbol=symbol, token=secret, version='v1')
# Out:
# [{'position': 8191472,
#   'reportDate': 1593129600000,
#   'entityName': 'Vincent Chiara'},
#  {'position': 3797530,
#   'reportDate': 1593129600000,
#   'entityName': 'Sébastien St. Louis'},
#  {'position': 3000001,
#   'reportDate': 1593129600000,
#   'entityName': 'Adam Miron'},
#  {'position': 1915653,
#   'reportDate': 1593129600000,
#   'entityName': 'Michael Munzar'},
#  {'position': 97727,
#   'reportDate': 1577404800000,
#   'entityName': 'Nathalie Bourque'},
#  {'position': 20000, 'reportDate': 1556668800000, 'entityName': None},
#  {'position': 15900, 'reportDate': 1557705600000, 'entityName': None},
#  {'position': 20,
#   'reportDate': 1593129600000,
#   'entityName': 'Roch Vaillancourt'},
#  {'position': 0, 'reportDate': 1556668800000, 'entityName': None},
#  {'position': 0, 'reportDate': 1557187200000, 'entityName': None}]

# %%
symbol = 'AAPL'
p.insiderSummary(symbol=symbol, token=secret, version='v1')
# Out:
# [{'reportedTitle': 'Director',
#   'netTransacted': 854,
#   'totalBought': 2283,
#   'totalSold': -1429,
#   'fullName': 'Susan Lynne Wagner'},
#  {'reportedTitle': 'Director',
#   'netTransacted': 854,
#   'totalBought': 2283,
#   'totalSold': -1429,
#   'fullName': 'James A. Bell'},
#  {'reportedTitle': 'Principal Accounting Officer',
#   'netTransacted': -6836,
#   'totalBought': 5916,
#   'totalSold': -12752,
#   'fullName': 'Chris Kondo'},
#  {'reportedTitle': 'COO',
#   'netTransacted': -85678,
#   'totalBought': 85678,
#   'totalSold': -171356,
#   'fullName': 'Jeffrey E. Williams'},
#  {'reportedTitle': 'Director',
#   'netTransacted': 854,
#   'totalBought': 11873,
#   'totalSold': -11019,
#   'fullName': 'Andrea Jung'},
#  {'reportedTitle': 'Director',
#   'netTransacted': -575,
#   'totalBought': 2283,
#   'totalSold': -2858,
#   'fullName': 'Arthur D. Levinson'},
#  {'reportedTitle': 'Director',
#   'netTransacted': 854,
#   'totalBought': 2283,
#   'totalSold': -1429,
# ...

# %%
symbol = 'AAPL'
p.insiderTransactions(symbol=symbol, token=secret, version='v1')
# Out:
# [{'fullName': 'Chris Kondo',
#   'reportedTitle': 'Principal Accounting Officer',
#   'effectiveDate': 1588896000000,
#   'tranShares': -4491,
#   'tranPrice': 305.62,
#   'tranValue': -1372539.42,
#   'directIndirect': 'D',
#   'tranCode': 'S'},
#  {'fullName': 'Andrea Jung',
#   'reportedTitle': 'Director',
#   'effectiveDate': 1588032000000,
#   'tranShares': -9590,
#   'tranPrice': None,
#   'tranValue': None,
#   'directIndirect': 'D',
#   'tranCode': 'M'},
#  {'fullName': 'Andrea Jung',
#   'reportedTitle': 'Director',
#   'effectiveDate': 1588032000000,
#   'tranShares': 9590,
#   'tranPrice': 48.95,
#   'tranValue': 469430.5,
#   'directIndirect': 'I',
#   'tranCode': 'M'},
#  {'fullName': "Deirdre O'Brien",
#   'reportedTitle': 'Senior Vice President',
#   'effectiveDate': 1586995200000,
#   'tranShares': -2161,
#   'tranPrice': 286.82,
#   'tranValue': -619818.02,
#   'directIndirect': 'D',
#   'tranCode': 'S'},
#  {'fullName': "Deirdre O'Brien",
# ...

# %%
symbol = 'AAPL'
p.intraday(symbol=symbol, token=secret, version='v1')
# Out:
# [{'date': '2020-07-06',
#   'minute': '09:30',
#   'label': '09:30 AM',
#   'high': 370.41,
#   'low': 369.9,
#   'average': 369.956,
#   'volume': 2302,
#   'notional': 851639.74,
#   'numberOfTrades': 16,
#   'marketHigh': 370.47,
#   'marketLow': 369.87,
#   'marketAverage': 370.011,
#   'marketVolume': 653165,
#   'marketNotional': 241678437.8582,
#   'marketNumberOfTrades': 1235,
#   'open': 370.02,
#   'close': 370.41,
#   'marketOpen': 370,
#   'marketClose': 370.46,
#   'changeOverTime': 0,
#   'marketChangeOverTime': 0},
#  {'date': '2020-07-06',
#   'minute': '09:31',
#   'label': '09:31 AM',
#   'high': 371.19,
#   'low': 370.44,
#   'average': 370.969,
#   'volume': 3525,
#   'notional': 1307664.2,
#   'numberOfTrades': 43,
#   'marketHigh': 371.22,
#   'marketLow': 370.43,
#   'marketAverage': 370.91,
#   'marketVolume': 281777,
#   'marketNotional': 104514039.9082,
#   'marketNumberOfTrades': 1188,
#   'open': 370.47,
#   'close': 371.19,
#   'marketOpen': 370.45,
# ...

# %%
p.ipoToday(token=secret, version='v1')
# Out:
# {'rawData': [], 'viewData': [], 'lastUpdate': '2020-07-05'}

# %%
p.ipoUpcoming(token=secret, version='v1')
# Out:
# {'rawData': [], 'viewData': []}

# %%
symbol = 'ACDVF'
p.keyStats(symbol=symbol, token=secret, version='v1')
# Out:
# {'week52change': -0.623581,
#  'week52high': 40.31,
#  'week52low': 6.49,
#  'marketcap': 3541595040,
#  'employees': None,
#  'day200MovingAvg': 25.73,
#  'day50MovingAvg': 12.9,
#  'float': 295469876,
#  'avg10Volume': 300751.2,
#  'avg30Volume': 689698.97,
#  'ttmEPS': 0.2243,
#  'ttmDividendRate': None,
#  'companyName': 'Air Canada',
#  'sharesOutstanding': 296616000,
#  'maxChangePercent': 2.2983,
#  'year5ChangePercent': 0.1857,
#  'year2ChangePercent': -0.2794,
#  'year1ChangePercent': -0.623494,
#  'ytdChangePercent': -0.68776,
#  'month6ChangePercent': -0.682678,
#  'month3ChangePercent': -0.108888,
#  'month1ChangePercent': -0.317386,
#  'day30ChangePercent': -0.068573,
#  'day5ChangePercent': -0.04243,
#  'nextDividendDate': None,
#  'dividendYield': None,
#  'nextEarningsDate': None,
#  'exDividendDate': None,
#  'peRatio': 54.48,
#  'beta': 1.3609929363607576}

# %%
symbol = 'AAPL'
p.largestTrades(symbol=symbol, token=secret, version='v1')
# Out:
# []

# %%
symbol = 'AAPL'
p.last(token=secret, version='v1')
# Out:
# [{'symbol': 'DRTT', 'price': 1.27, 'size': 400, 'time': 1593707975291},
#  {'symbol': 'OI', 'price': 9.3, 'size': 12, 'time': 1593719997043},
#  {'symbol': 'GPM', 'price': 5.445, 'size': 300, 'time': 1593719916769},
#  {'symbol': 'KTOS', 'price': 15.445, 'size': 3, 'time': 1593719979399},
#  {'symbol': 'BZF', 'price': 16.32, 'size': 100, 'time': 1551969819695},
#  {'symbol': 'DARE', 'price': 0.9919, 'size': 96, 'time': 1593719946730},
#  {'symbol': 'AIKI', 'price': 0.8152, 'size': 48, 'time': 1593719381658},
#  {'symbol': 'USHG', 'price': 27.19, 'size': 1, 'time': 1593098224435},
#  {'symbol': 'POR', 'price': 42.715, 'size': 100, 'time': 1593719986008},
#  {'symbol': 'HECCU', 'price': 10.23, 'size': 100, 'time': 1593705222097},
#  {'symbol': 'FDEF', 'price': 18.13, 'size': 4, 'time': 1592596793716},
#  {'symbol': 'EARS', 'price': 0.9599, 'size': 100, 'time': 1593699250957},
#  {'symbol': 'STZ', 'price': 185.67, 'size': 100, 'time': 1593719997613},
# ...

# %%
p.marketNews(token=secret, version='v1')
# Out:
# [{'datetime': 1593958680000,
#   'headline': "Stock Market Update For The Week Ahead: 'Continued Strength'",
#   'source': 'Benzinga',
#   'url': 'https://cloud.iexapis.com/v1/news/article/35258ae5-ec06-43e5-91ee-4426d5735321',
#   'summary': 'The Last Week In A Nutshell What Happened: The S&P 500 experienced its best quarter since 1998, adding 20%. "A 20% quarterly gain is quite …',
#   'related': 'SP500',
#   'image': 'https://cloud.iexapis.com/v1/news/image/35258ae5-ec06-43e5-91ee-4426d5735321',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1593950400000,
#   'headline': 'Coronavirus Is No Cure for Health-Care Stocks',
#   'source': 'The Wall Street Journal',
#   'url': 'https://cloud.iexapis.com/v1/news/article/7c7ce912-6820-42c0-8a28-02463dde8a32',
#   'summary': 'The S&P 500’s health-care sector finished June as the second-worst performer of the index’s 11 groups, a shift from earlier this year when the stocks offered shelter during market turbulence.',
# ...

# %%
import requests
requests.get('https://cloud.iexapis.com/v1/news/article/d34120d3-9979-43e4-bb1a-f49d36a8660e')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ...

# %%
symbol = 'HEXO'
p.news(count=100, symbol=symbol, token=secret, version='v1')
# Out:
# [{'datetime': 1593019550000,
#   'headline': 'ESPAÑOL • Dividendos en ETFs MJ y THCX, Canopy Growth, Entrevista en el Cumpleaños del Duki, y Cannabis en Israel',
#   'source': 'Benzinga Feeds',
#   'url': 'https://cloud.iexapis.com/v1/news/article/ae28f636-a7e1-4845-a232-87aea8bd4036',
# ...

# %%
symbol = 'HEXO'
p.ohlc(symbol=symbol, token=secret, version='v1')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-140067971920> in <module>
#       1 symbol = 'HEXO'
# ----> 2 p.ohlc('2020-07-10',symbol=symbol, token=secret, version='v1')
#
# TypeError: ohlc() got multiple values for argument 'symbol'

# %%
symbol = 'HEXO'
p.price(symbol=symbol, token=secret, version='v1')
# Out:
# 0.6942

# %%
symbol = 'AAPL'
p.priceTarget(symbol=symbol, token=secret, version='v1')
# Out:
# {'symbol': 'AAPL',
#  'updatedDate': '2020-07-01',
#  'priceTargetAverage': 341.49,
#  'priceTargetHigh': 425,
#  'priceTargetLow': 195.43,
#  'numberOfAnalysts': 37,
#  'currency': 'USD'}

# %%
symbol = 'HEXO'
p.quote(symbol=symbol, token=secret, version='v1')
# Out:
# {'symbol': 'HEXO',
#  'companyName': 'HEXO Corp.',
#  'primaryExchange': 'New York Stock Exchange',
#  'calculationPrice': 'close',
#  'open': 0.71,
#  'openTime': 1594215001011,
#  'openSource': 'official',
#  'close': 0.6942,
#  'closeTime': 1594238402059,
#  'closeSource': 'official',
#  'high': 0.715,
#  'highTime': 1594252702854,
#  'highSource': '15 minute delayed price',
#  'low': 0.6812,
#  'lowTime': 1594234566398,
#  'lowSource': '15 minute delayed price',
#  'latestPrice': 0.6942,
#  'latestSource': 'Close',
#  'latestTime': 'July 8, 2020',
#  'latestUpdate': 1594238402059,
#  'latestVolume': 5214983,
#  'iexRealtimePrice': 0,
#  'iexRealtimeSize': 0,
#  'iexLastUpdated': 0,
#  'delayedPrice': 0.6939,
#  'delayedPriceTime': 1594252702854,
#  'oddLotDelayedPrice': 0.6902,
#  'oddLotDelayedPriceTime': 1594238399003,
#  'extendedPrice': 0.84,
#  'extendedChange': 0.1458,
#  'extendedChangePercent': 0.21003,
#  'extendedPriceTime': 1594296016103,
#  'previousClose': 0.7011,
# ...

# %%
symbol = 'AAPL'
p.recent(token=secret, version='v1')
# Out:
# [{'date': '2020-07-02',
#   'volume': 182738085,
#   'routedVolume': 35027377,
#   'marketShare': 0.01807,
#   'isHalfday': False,
#   'litVolume': 23580970},
#  {'date': '2020-07-01',
#   'volume': 209855962,
#   'routedVolume': 39294698,
#   'marketShare': 0.01926,
#   'isHalfday': False,
#   'litVolume': 28047296},
#  {'date': '2020-06-30',
#   'volume': 204153317,
#   'routedVolume': 40216418,
#   'marketShare': 0.01832,
#   'isHalfday': False,
#   'litVolume': 27244503},
#  {'date': '2020-06-29',
#   'volume': 225469704,
#   'routedVolume': 32570342,
#   'marketShare': 0.02068,
#   'isHalfday': False,
#   'litVolume': 26373022},
#  {'date': '2020-06-26',
#   'volume': 283424613,
#   'routedVolume': 51786980,
#   'marketShare': 0.015780000000000002,
#   'isHalfday': False,
#   'litVolume': 34793610}]

# %%
symbol = 'JFIN'
p.relevant(symbol=symbol, token=secret, version='v1')
# Out:
# {'peers': True, 'symbols': ['PERI', 'PBYA', 'PIKL', 'PINS']}

# %%
p.sectorPerformance(token=secret, version='v1')
# Out:
# [{'type': 'sector',
#   'name': 'Materials',
#   'performance': 0.01877,
#   'lastUpdated': 1593720000052},
#  {'type': 'sector',
#   'name': 'Energy',
#   'performance': 0.0111,
#   'lastUpdated': 1593720000186},
#  {'type': 'sector',
#   'name': 'Industrials',
#   'performance': 0.00863,
#   'lastUpdated': 1593720000186},
#  {'type': 'sector',
#   'name': 'Health Care',
#   'performance': 0.00754,
#   'lastUpdated': 1593720000227},
#  {'type': 'sector',
#   'name': 'Technology',
#   'performance': 0.00583,
#   'lastUpdated': 1593720000038},
#  {'type': 'sector',
#   'name': 'Consumer Staples',
#   'performance': 0.00511,
#   'lastUpdated': 1593720000023},
#  {'type': 'sector',
#   'name': 'Consumer Discretionary',
#   'performance': 0.00395,
#   'lastUpdated': 1593720000227},
#  {'type': 'sector',
#   'name': 'Utilities',
#   'performance': 0.0026,
#   'lastUpdated': 1593720000038},
#  {'type': 'sector',
#   'name': 'Financials',
#   'performance': 0.00131,
# ...

# %%
p.sectors(token=secret, version='v1')
# Out:
# [{'name': 'Electronic Technology'},
#  {'name': 'Distribution Services'},
#  {'name': 'Health Technology'},
#  {'name': 'Commercial Services'},
#  {'name': 'Industrial Services'},
#  {'name': 'Finance'},
#  {'name': 'Process Industries'},
#  {'name': 'Transportation'},
#  {'name': 'Technology Services'},
#  {'name': 'Producer Manufacturing'},
#  {'name': 'Retail Trade'},
#  {'name': 'Consumer Services'},
#  {'name': 'Non-Energy Minerals'},
#  {'name': 'Utilities'},
#  {'name': 'Miscellaneous'},
#  {'name': 'Health Services'},
#  {'name': 'Consumer Durables'},
#  {'name': 'Consumer Non-Durables'},
#  {'name': 'Communications'},
#  {'name': 'Energy Minerals'},
#  {'name': 'Government'}]

# %%
p.securitySwap(token=secret, version='v1')
# Out:
# [{'countryCode': 'US',
#   'created': '2020-06-26',
#   'description': 'International Value Fund Class 1',
#   'exDate': '2020-10-19',
#   'figi': 'BBG000JWW6B7',
#   'flag': 'Stock',
#   'fromFactor': 0,
#   'lastUpdated': '2020-06-26',
#   'notes': '(As on 26/06/20) EDI <BR>Issuer Name John Hancock Funds II<BR>Fund Name International Value Fund Class 1<BR>Cusip/ISIN US47803V6487<BR>Symbol JIVIX<BR>New Issuer CIK 0000022370<BR>New Issuer Name John Hancock Investment Trust<BR>New Fund Name John Hancock Disciplined Value International Fund Class I<BR>New Cusip/ISIN US47803P2948<BR>New Symbol JDVIX<BR>Form Type 497<BR>CA Type Reorganization<BR>Effective Date 19-Oct-20<BR>De-Listing Date 19-Oct-20<BR>Link  https://www.sec.gov/Archives/edgar/data/1331971/000113322820004048/jhfiiivf-html2737_497.htm<BR>Old ISIN Link  <BR>',
#   'parValue': 0,
#   'parValueCurrency': 'USD',
#   'paymentDate': None,
#   'ratio': None,
#   'recordDate': None,
#   'refid': '6619180',
# ...

# %%
symbol = 'HEXO'
p.splits(symbol=symbol, token=secret, version='v1')
# Out:
# [{'symbol': 'HEXO',
#   'exDate': None,
#   'recordDate': None,
#   'paymentDate': None,
#   'fromFactor': 2.8000716,
#   'toFactor': 1,
#   'ratio': 2.8000716,
#   'description': 'Ordinary Shares',
#   'splitType': 'Reverse Split',
#   'flag': 'Stock',
#   'securityType': 'Equity Shares',
# ...

# %%
p.summary(token=secret, version='v1')
# Out:
# [{'averageDailyVolume': 230341495.6,
#   'averageDailyRoutedVolume': 55343325.45,
#   'averageMarketShare': 0.02035,
#   'averageOrderSize': 293,
#   'averageFillSize': 174,
#   'bin100Percent': 0.73553,
#   'bin101Percent': 0.02425,
#   'bin200Percent': 0.10466,
#   'bin300Percent': 0.04648,
#   'bin400Percent': 0.02266,
#   'bin500Percent': 0.04072,
#   'bin1000Percent': 0.02318,
#   'bin5000Percent': 0.00169,
#   'bin10000Percent': 0.00084,
#   'bin10000Trades': 5986,
#   'bin20000Trades': 1607,
#   'bin50000Trades': 223,
#   'uniqueSymbolsTraded': 8348,
#   'blockPercent': 0.05284,
#   'selfCrossPercent': 0.04309,
#   'etfPercent': 0.10089,
#   'largeCapPercent': 0.38345,
#   'midCapPercent': 0.26878,
#   'smallCapPercent': 0.24688,
#   'venueARCXFirstWaveWeight': 0.12303,
#   'venueBATSFirstWaveWeight': 0.13181,
#   'venueBATYFirstWaveWeight': 0.00588,
#   'venueEDGAFirstWaveWeight': 0.00949,
#   'venueEDGXFirstWaveWeight': 0.07183,
#   'venueOverallFirstWaveWeight': 1,
# ...

# %%
p.symbols(token=secret, version='v1')
# Out:
# [{'symbol': 'A',
#   'exchange': 'NYS',
#   'name': 'Agilent Technologies Inc.',
#   'date': '2020-07-05',
#   'type': 'cs',
#   'iexId': 'IEX_46574843354B2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000C2V3D6',
#   'cik': '1090872'},
#  {'symbol': 'AA',
#   'exchange': 'NYS',
#   'name': 'Alcoa Corp.',
#   'date': '2020-07-05',
#   'type': 'cs',
#   'iexId': 'IEX_4238333734532D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00B3T3HD3',
#   'cik': '1675149'},
#  {'symbol': 'AAAU',
#   'exchange': 'PSE',
#   'name': 'Perth Mint Physical Gold ETF',
#   'date': '2020-07-05',
#   'type': 'et',
#   'iexId': 'IEX_474B433136332D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00LPXX872',
#   'cik': None},
#  {'symbol': 'AACG',
#   'exchange': 'NAS',
#   'name': 'ATA Creativity Global Sponsored ADR',
#   'date': '2020-07-05',
#   'type': 'ad',
# ...

# %%
p.tags(token=secret, version='v1')
# Out:
# [{'name': 'Electronic Technology'},
#  {'name': 'Distribution Services'},
#  {'name': 'Commercial Services'},
#  {'name': 'Health Technology'},
#  {'name': 'Industrial Services'},
#  {'name': 'Finance'},
#  {'name': 'Transportation'},
#  {'name': 'Process Industries'},
#  {'name': 'Technology Services'},
#  {'name': 'Producer Manufacturing'},
#  {'name': 'Retail Trade'},
#  {'name': 'Consumer Services'},
#  {'name': 'Non-Energy Minerals'},
#  {'name': 'Utilities'},
#  {'name': 'Miscellaneous'},
#  {'name': 'Health Services'},
#  {'name': 'Consumer Durables'},
#  {'name': 'Consumer Non-Durables'},
#  {'name': 'Communications'},
#  {'name': 'Energy Minerals'},
#  {'name': 'Homebuilding'},
#  {'name': 'Semiconductors'},
#  {'name': 'Office Equipment/Supplies'},
#  {'name': 'Biotechnology'},
#  {'name': 'Tools & Hardware'},
#  {'name': 'Oilfield Services/Equipment'},
#  {'name': 'Other Metals/Minerals'},
#  {'name': 'Investment Managers'},
#  {'name': 'Department Stores'},
# ...

# %%
symbol = 'AAPL'
p.upcomingEarnings(symbol=symbol, token=secret, version='v1')
# Out:
# [{'symbol': 'AAPL', 'reportDate': '2020-07-30'}]

# %%
symbol = 'GOOG'
p.upcomingEvents(symbol=symbol, token=secret, version='v1')
# Out:
# {'earnings': [{'symbol': 'GOOG', 'reportDate': '2020-07-23'}],
#  'dividends': [],
#  'splits': []}

# %%
symbol = 'GOOG'
p.upcomingIPOs(symbol=symbol, token=secret, version='v1')
# Out:
# {'rawData': [], 'viewData': []}

# %%
symbol = 'HEXO'
p.volumeByVenue(symbol=symbol, token=secret, version='v1')
# Out:
# [{'volume': 0,
#   'venue': 'XCHI',
#   'venueName': 'CHX',
#   'marketPercent': 0,
#   'avgMarketPercent': 0,
#   'date': None},
#  {'volume': 200,
#   'venue': 'EDGA',
#   'venueName': 'Cboe EDGA',
#   'date': '2020-07-02',
#   'marketPercent': 6.368201785389053e-05,
#   'avgMarketPercent': 0.007376134298603812},
#  {'volume': 800,
#   'venue': 'IEXG',
#   'venueName': 'IEX',
#   'date': '2020-07-02',
#   'marketPercent': 0.00014507658139367456,
#   'avgMarketPercent': 0.004789332107424224},
#  {'volume': 1018,
#   'venue': 'XCIS',
#   'venueName': 'NYSE National',
#   'date': '2020-07-02',
#   'marketPercent': 0.00015915217230208145,
#   'avgMarketPercent': 0.002190123111531002},
#  {'volume': 1100,
#   'venue': 'XASE',
#   'venueName': 'NYSE American',
#   'date': '2020-07-02',
#   'marketPercent': 0.000608034456759906,
#   'avgMarketPercent': 0.0013446904030784486},
#  {'volume': 4065,
#   'venue': 'XPHL',
#   'venueName': 'Nasdaq PSX',
#   'date': '2020-07-02',
# ...

# %%
symbol = 'GOOG'
p.yesterday(symbol=symbol, token=secret, version='v1')
# Out:
# {'date': '2020-07-02',
#  'open': 1446.94,
#  'close': 1464.7,
#  'high': 1482.95,
#  'low': 1446.42,
#  'volume': 1859480,
#  'uOpen': 1446.94,
#  'uClose': 1464.7,
#  'uHigh': 1482.95,
#  'uLow': 1446.42,
#  'uVolume': 1859480,
#  'change': 26.66,
#  'changePercent': 1.8539,
#  'changeOverTime': 0,
#  'symbol': 'GOOG'}
