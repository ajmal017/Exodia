# %%
import time
import datetime
import requests
import json
import os
import numpy as np

import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

from textblob import TextBlob
#nltk.download('vader_lexicon')

# %%
class CommentSentiment(object):
    def __init__(self, ticker, popularOrNewest):
        self.placeholder = 'placeholder'
        self.popularNewest = popularOrNewest
        self.Stocktwits_URL = f'https://api.stocktwits.com/api/2/streams/symbol/{self.placeholder}.json?filter=top'
        self.Yahoo_URL = f'https://finance.yahoo.com/_finance_doubledown/api/resource/canvass.getMessageListForContext_ns;context=finmb_{self.placeholder};count=30;index=null;lang=en-US;namespace=yahoo_finance;oauthConsumerKey=finance.oauth.client.canvass.prod.consumerKey;oauthConsumerSecret=finance.oauth.client.canvass.prod.consumerSecret&sortBy={self.popularNewest}'
        self.ticker = ticker.upper()
        
    def getYahooIdWithTicker(self):
        agent = {"User-Agent":'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/83.0.4103.61 Chrome/83.0.4103.61 Safari/537.36'}
        txt = requests.get(f'http://thelion.com/bin/aio_msg.cgi?cmd=search&symbol={self.ticker}&x=0&y=0',headers=agent)
        spli = txt.text.split('<a href="https://finance.yahoo.com/_finance_doubledown/api/resource/canvass.getMessageListForContext_ns;context=finmb_')
        Id = spli[1][:9]
        return Id
        
    def getStocktwitsComments(self):
        agent = {"User-Agent":'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/83.0.4103.61 Chrome/83.0.4103.61 Safari/537.36'}
        comments = requests.get(self.Stocktwits_URL.replace(self.placeholder,self.ticker),agent)
        return comments.json()
    
    def getYahooComments(self):
        agent = {"User-Agent":'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/83.0.4103.61 Chrome/83.0.4103.61 Safari/537.36'}
        tickerId = self.getYahooIdWithTicker()
        comments = requests.get(self.Yahoo_URL.replace(self.placeholder,tickerId),agent)
        return comments.json()
    
    def saveStocktwitsComment(self,comments):
        # datas = ['ideas','followers','following','likes/total','replies','watchlist_stocks_count','join_date']
        # 'entities', 'sentiment'
        
        msgFirst = comments['messages'][0]
        msgLast = comments['messages'][-1]
        
        msgFirstTime = time.mktime(datetime.datetime.strptime(msgFirst['created_at'], "%Y-%m-%dT%H:%M:%SZ").timetuple())
        msgLastTime = time.mktime(datetime.datetime.strptime(msgLast['created_at'], "%Y-%m-%dT%H:%M:%SZ").timetuple())
        timeDelta = (msgFirstTime-msgLastTime)/60
        
        old_data = {}
        last_comment = ''
        if os.path.isfile(f'./comments/stocktwits/{self.ticker}.json'):
            with open(f'./comments/stocktwits/{self.ticker}.json','r') as JSON:
                old_data = json.load(JSON)
                last_comment = old_data['last_comment']
                JSON.close()
        
        DATE = str(datetime.datetime.now()).split(' ')[0]
        TIME = str(datetime.datetime.now()).split(' ')[1].split('.')[0]
        
        body = {'first_last_delta':timeDelta,'average_sentiment':0,'adjusted_sentiment':0,'comments':{}}
        totalSentiment = 0
        adjustedSentiment = 0
        sentimentDivider = 0
        cc = 0
        for msg in comments['messages']:
            uID = msg['id']
            uBody = msg['body'] 
            uCreatedAt = msg['created_at']
            uFollowers = int(msg['user']['followers'])
            uFollowing = int(msg['user']['following'])
            uWatchListCount = int(msg['user']['watchlist_stocks_count'])
            uJoinDate = msg['user']['join_date']
             
            try:
                uLikes = int(msg['likes']['total'])
            except:
                uLikes = 0   
            try:
                uReplies = int(msg['conversation']['replies'])
            except:
                uReplies = 0
            try:
                uSentiment = msg['entities']['sentiment']['basic']
            except:
                uSentiment = 'None'


            if uSentiment == 'Bullish':
                uSentimentAnalysis = 1.0
            elif uSentiment == 'Bearish':
                uSentimentAnalysis = -1.0
            else:
                blob = TextBlob(uBody)
                blob.tags
                blob.noun_phrases 
                total = []
                if len(blob.sentences) > 0:
                    for sentence in blob.sentences:
                        print(sentence,sentence.sentiment.polarity)
                        total += [sentence.sentiment.polarity]
                    uSentimentAnalysis = sum(total)/len(total) #sia.polarity_scores(uBody)
                else:
                    uSentimentAnalysis = 0.0

            multiplier = (uLikes/(1+uFollowers))**0.6 * uFollowers
            adjustedSentiment += uSentimentAnalysis + (multiplier*uSentimentAnalysis)
            sentimentDivider += (multiplier + 1)
            totalSentiment += uSentimentAnalysis
            
#             print(f'Sentiment: {uSentimentAnalysis}')
#             print(f'Adj Sentiment: {uSentimentAnalysis + (multiplier*uSentimentAnalysis)}')
#             print(msg['user']['username'])
#             print(f'Followers: {uFollowers}')
            
            formatted = {
                'body':uBody,
                'created_at':uCreatedAt,
                'followers':uFollowers,
                'following':uFollowing,
                'likes':uLikes,
                'watchlist_stocks_count':uWatchListCount,
                'join_date':uJoinDate,
                'replies':uReplies,
                'sentiment':uSentiment,
                'sentiment_analysis':uSentimentAnalysis
            }
            body['comments'][uID] = formatted
            cc += 1
#             print(f'Comment {cc} done.\n')
            
        body['average_sentiment'] = totalSentiment/cc
        body['adjusted_sentiment'] = adjustedSentiment/sentimentDivider
        
        print('\n\n\n')
        print(f'Adj Sentiment: {adjustedSentiment/sentimentDivider}')
        print(f'Sentiment: {totalSentiment/cc}')
        
        old_data['last_comment'] = msgFirst['body']
        if DATE not in old_data.keys():
            old_data[DATE] = {}
            
        old_data[DATE][TIME] = body
        with open(f'./comments/stocktwits/{self.ticker}.json','w') as JSON:
            json.dump(old_data,JSON)
            JSON.close()
    
    def saveYahooComment(self,comments):
        # datas = ['ideas','followers','following','likes/total','replies','watchlist_stocks_count','join_date']
        # 'entities', 'sentiment'
        
        # canvasMessages -> "author" -> "createdAt,details[userText],reactionStats[upVoteCount,downVoteCount,replyCount]
        
        msgFirst = comments['canvassMessages'][0]
        msgLast = comments['canvassMessages'][-1]
        
        msgFirstTime = msgFirst['meta']['createdAt']
#         return msgFirst
        msgLastTime = msgLast['meta']['createdAt']
        timeDelta = (msgFirstTime-msgLastTime)/60
        
        old_data = {}
        last_comment = ''
        if os.path.isfile(f'./comments/yahoo/{self.ticker}.json'):
            with open(f'./comments/yahoo/{self.ticker}.json','r') as JSON:
                old_data = json.load(JSON)
                last_comment = old_data['last_comment']
                JSON.close()
        
        DATE = str(datetime.datetime.now()).split(' ')[0]
        TIME = str(datetime.datetime.now()).split(' ')[1].split('.')[0]
        
        body = {'first_last_delta':timeDelta,'average_sentiment':0,'adjusted_sentiment':0,'comments':{}}
        totalSentiment = 0
        adjustedSentiment = 0
        sentimentDivider = 0
        cc = 0
        for msg in comments['canvassMessages']:
            uID = msg['meta']['author']['guid']
            uBody = msg['details']['userText']
            uCreatedAt = msg['meta']['createdAt']
            uFollowers = 0 #int(msg['user']['followers'])
            uFollowing = 0 #int(msg['user']['following'])
            uWatchListCount = 0 #int(msg['user']['watchlist_stocks_count'])
            uJoinDate = 0 #msg['user']['join_date']
             
            try:
                uLikes = int(msg['reactionStats']['upVoteCount'])
            except:
                uLikes = 0   
            try:
                uDislikes = int(msg['reactionStats']['downVoteCount'])
            except:
                uDislikes = 0   
            try:
                uReplies = int(msg['reactionStats']['replyCount'])
            except:
                uReplies = 0
            try:
                uSentiment = msg['userLabels']
            except:
                uSentiment = 'None'


            if uSentiment == 'Bullish':
                uSentimentAnalysis = 1.0
            elif uSentiment == 'Bearish':
                uSentimentAnalysis = -1.0
            else:
                blob = TextBlob(uBody)
                blob.tags
                blob.noun_phrases 
                total = []
                if len(blob.sentences) > 0: 
                    for sentence in blob.sentences:
                        print(sentence,sentence.sentiment.polarity)
                        total += [sentence.sentiment.polarity]
                    uSentimentAnalysis = sum(total)/len(total) #sia.polarity_scores(uBody)
                else:
                    uSentimentAnalysis = 0.0

            uLikes += 1
            uDislikes += 1 
            
            Total = uLikes + uDislikes
            likeRatio = uLikes/Total
            dislikeRatio = uDislikes/Total
            sentimentSum = Total * ((likeRatio*uSentimentAnalysis) - (dislikeRatio*uSentimentAnalysis))
            adjustedSentiment += uSentimentAnalysis + sentimentSum
            sentimentDivider += (1 + (Total-2))
            totalSentiment += uSentimentAnalysis
            
#             print(f'Sentiment: {adjustedSentiment}')
#             print(msg['meta']['author']['nickname'])
#             print(f'Followers: {uFollowers}')
            
            formatted = {
                'body':uBody,
                'created_at':uCreatedAt,
                'followers':uFollowers,
                'following':uFollowing,
                'likes':uLikes,
                'dislikes':uDislikes,
                'watchlist_stocks_count':uWatchListCount,
                'join_date':uJoinDate,
                'replies':uReplies,
                'sentiment':uSentiment,
                'sentiment_analysis':uSentimentAnalysis
            }
            body['comments'][uID] = formatted
            cc += 1
#             print(f'Comment {cc} done.\n')
            
        body['average_sentiment'] = totalSentiment/cc
        body['adjusted_sentiment'] = adjustedSentiment/sentimentDivider
        
        print('\n\n\n')
        print(f'Adj Sentiment: {adjustedSentiment/sentimentDivider}')
        print(f'Sentiment: {totalSentiment/cc}')
        
        old_data['last_comment'] = msgFirst['details']['userText']
        if DATE not in old_data.keys():
            old_data[DATE] = {}
            
        old_data[DATE][TIME] = body
        with open(f'./comments/yahoo/{self.ticker}.json','w') as JSON:
            json.dump(old_data,JSON)
            JSON.close()
    
    
    
    def parseStocktwitsComments(self, ticker):
        # Time interval: 30min
        data = {}
        try:
            with open(f'./comments/stocktwits/{ticker.upper()}.json','r') as JSON:
                data = json.load(JSON)
                JSON.close()
        except:
            print("This stock doesn't have any data yet.")
            return
        
        old_data = {}
        if os.path.isfile(f'./comments/p/stocktwits/{ticker.upper()}.json'):
            with open(f'./comments/p/stocktwits/{ticker.upper()}.json','r') as JSON:
                old_data = json.load(JSON)
                JSON.close()
            
        for line in data:
            if line == "last_comment":
                continue
            
            formatted = {}
            for timestamp in data[line]:
                tmp = {}
                hour = timestamp[0:2]
                minute = int(timestamp[3:5])
                
                if minute < 30:
                    minute = '00'
                else:
                    minute = '30'
                    
                tmp['first_last_delta'] = data[line][timestamp]['first_last_delta']
                tmp['average_sentiment'] = data[line][timestamp]['average_sentiment']
                tmp['adjusted_sentiment'] = data[line][timestamp]['adjusted_sentiment']
                
                formatted[hour+':'+minute] = tmp
                
            old_data[line] = formatted
            
        with open(f'./comments/p/stocktwits/{ticker.upper()}.json','w') as JSON:
            json.dump(old_data,JSON)
            JSON.close()

        print('Done.')
    
    
    
    
    def parseYahooComments(self, ticker):
        # Time interval: 30min
        data = {}
        try:
            with open(f'./comments/yahoo/{ticker.upper()}.json','r') as JSON:
                data = json.load(JSON)
                JSON.close()
        except:
            print("This stock doesn't have any data yet.")
            return
        
        old_data = {}
        if os.path.isfile(f'./comments/p/yahoo/{ticker.upper()}.json'):
            with open(f'./comments/p/yahoo/{ticker.upper()}.json','r') as JSON:
                old_data = json.load(JSON)
                JSON.close()
            
        for line in data:
            if line == "last_comment":
                continue
            
            formatted = {}
            for timestamp in data[line]:
                tmp = {}
                hour = timestamp[0:2]
                minute = int(timestamp[3:5])
                
                if minute < 30:
                    minute = '00'
                else:
                    minute = '30'
                    
                tmp['first_last_delta'] = data[line][timestamp]['first_last_delta']
                tmp['average_sentiment'] = data[line][timestamp]['average_sentiment']
                tmp['adjusted_sentiment'] = data[line][timestamp]['adjusted_sentiment']
                
                formatted[hour+':'+minute] = tmp
                
            old_data[line] = formatted
            
        with open(f'./comments/p/yahoo/{ticker.upper()}.json','w') as JSON:
            json.dump(old_data,JSON)
            JSON.close()

        print('Done.')
    
    
    
    
    def saveStocktwits(self):
        comments = self.getStocktwitsComments()
        self.saveStocktwitsComment(comments)
        
    def saveYahoo(self):
        comments = self.getYahooComments()
        self.saveYahooComment(comments)

# %%
ticker = 'TSLA'
cc = CommentSentiment(ticker,'newest')

# %%
cc.parseStocktwitsComments(ticker)
# Out:
# Done.

# %%
cc.parseYahooComments(ticker)
# Out:
# Done.

# %%
cc.saveStocktwits()
# Out:
# $TSLA Looks like $2,000 is coming by freaking end of week 0.0
# Bitcoin scammers move on from Elon Musk, pose as Joe Rogan $TSLA
# ► https://decrypt.co/?p=34733 0.0
# $TSLA this is a buy and forget 0.0
# $TSLA what’s the best way to buy into TSLA right now? 0.6428571428571428
# Tesla &#39;s weekly $1600 calls are going for $13.00. 0.0
# Might be a good idea to be a vol seller after the current run. 0.35
# I&#39;d bet these are down by ~50% by Wednesday&#39;s close. -0.15555555555555559
# $TSLA 0.0
# $TSLA Damn it hit 1320? 0.0
# $TSLA up 45% in a week...lol
# Something is definitely going to give 0.0
# $TSLA fall of any kind will be violent -0.10000000000000003
# $TSLA looking at the February chart. 0.0
# This run up is starting to look eerie similarly 🤔 -0.16666666666666666
# $TSLA is anyone keeping it till tomorrow? 0.0
# $TSLA I sold 800 shares last years at $190. 0.0
# Yes, I feel very stupid everyday. -0.6
# $TSLA expectation extremely high there is no room for the slightest failure! -0.11791666666666668
# $TSLA I hate to say it, but it&#39;s still got another 3-400 in it -0.8
# $TSLA 25 million shares.. Have. 0.0
# Been bought?? 0.0
# What is today&#39;s shares  vol 0.0
#
#
#
#
# Adj Sentiment: 0.4577539098216126
# Sentiment: 0.17634060846560845

# %%
cc.saveYahoo()
# Out:
# Not sure why we debate about this stock. -0.25
# Fan followers will believe what they want and vice versa is true as well. 0.35
# While the numbers might not justify the stock value.. who cares when folks are willing to pay for it. 0.25
# Tesla is quite possibly the MOST overvalued company in the world right now. 0.2619047619047619
# Toyota doesn't sell solar roofs, nor provide city-wide battery back-up to the local electrical grids like Tesla and Toyota isn't a large electrical utility provider nor does Toyota offer auto insurance to their customers. 0.10714285714285714
# Tesla seems to be the only company able to sell cars because they're being sold to wealthy people. 0.3333333333333333
# This is only the beginning of Tesla, can anyone imagine 10 to 20 years from now. 0.0
# Tesla has posted four profitable quarters so far. 0.1
# With Tesla you’re buying their battery technology and their self driving tech. 0.0
# There are at least 5 years ahead of any other company in the World. -0.2125
# Tesla is a
# technology company more like Amazon and Apple. 0.5
# They simply sell something nobody else has for another 5 years. 0.0
# Tesla  stock is dirt cheap! 0.5
# When Tesla's shares are over $5000 in 5 years remember I told you. 0.0
# Newsome lockdown coming again? 0.0
# Lets see how this plays out. 0.0
# 72000 cars in 3 months... That's about how many Toyota sells every 3 days 0.5
# How convenient another pharmaceutical company announcement about COVID drug at 920 am this morning to pump market more in an epidemic first was moderna then another one can’t even remember but they all make breakthrough announcements right before the open complete scam 0.22714285714285715
# Tesla is headed for a disaster. 0.0
# It's lineup of electric cars is about to become ordinary, common place. -0.275
# The competition is bringing out the same product, and probably for less cost. -0.08333333333333333
# But it's the future that drives Tesla stock, especially the fully autonomous dream, of Tesla owners letting their cars roam free, picking up strays who are not so fortunate as to own a Musk-mobile. 0.30000000000000004
# But that is a false dream. -0.4000000000000001
# Instead, Alphabet, Amazon, and Apple - which are developing real autonomous vehicles that will be able to navigate city streets at 35 mph and not just parking lot maneuvers at 2 mph - will populate the cities with their autonomous corporate owned fleets, putting a dagger into the heart of Tesla hype. 0.375
# Indeed, Musk made a fool's errand by declaring his approach with cameras and radar as sufficient when it is only good for second-rate driver's assist and parking lot maneuvers. 0.35
# So he is so far behind of the curve in the development of the necessary LIDAR technology that he cannot catch up - indeed, he doesn't even realize the need - well, at this point he probably does but he knows it's too late in the game to change his approach so he might as well hype his infallibility to milk his dead-end approach as much as possible before he is discovered by the fawning masses. -0.16666666666666666
# This is why Tesla stock will essentially disappear once these tech behemoths, with tens of thousands of world-class scientists and engineers working on the problem, flood the streets with their truly autonomous ride service fleets. 0.2
# Look like it set up for 1200 tomorrow based on the call options 0.0
# Thinking it could hit 1250 tomorrow? 0.0
# Any thoughts for a good selling point? 0.7
# #$%$  We might be waiting for a while for the market to totally crash. 0.0
# Around 11:00 a.m. California time on Wednesday, Tesla CEO Elon Musk sent out an e-mail congratulating his tens of thousands of employees. 0.0
# "Just amazing how well you executed, especially in such difficult times. 0.03333333333333336
# I am so proud to work with you!" 1.0
# read the email in its entirety. 0.0
# Less than 1000 car sales a day and you cheerleaders are dancing and celebrating being in S&P500 and highest valued car stock in the world. -0.16666666666666666
# Meanwhile, CA is shutting back down and USA new COVID cases were almost 53000. -0.006397306397306411
# Is there any particular reason why Falsi "Big Ears" MD [ The Man behind Mask] sometimes wore the Mask while testifying in Congress and sometimes not ? -0.07777777777777779
# Was it some kind of manifestation of Science Behind Mask that regular folk does not understand............ 0.06666666666666665
# Why not report the sales numbers before the bell tomorrow? 0.0
# Why wait until after the bell as reported by CNBC? 0.0
# Elon Musk has certainly been told the number since he sent an email to his employees. 0.21428571428571427
# The only reason can be that they are deliberately manipulating the share price by maintaining the suspense to harm shorts and weekly put holders. 0.0
# The SEC should investigate and penalize this inappropriate behavior. -0.1
# This is so over valued I just can’t wait. 0.0
# What the heck were people doing after hours, pushing stock up another 18 points. 0.0
# Were they sleeping during normal hours? 0.15
# I've bought and sold so many times these days and it's still going up, amazing. 0.55
# Seriously I think it'll peak tomorrow. -0.3333333333333333
# It releases delivery number tomorrow after market, and there should be a sell on news next Monday. 0.0
# I sold 17 shares of Tesla and bought 1000 shares of WKHS early today. 0.1
# They should report before the bell, since they obviously know the numbers now. 0.0
# They are just trying to destroy shorts and July 2 put holders. -0.2
# More manipulation. 0.5
# If BA got good certification news tomorrow the market will blast off and Tesla will +$100 minimum 0.7
# Pure stock manipulation. 0.21428571428571427
# Where is the SEC? -0.1
# Also, why is Musk providing advance info to his employees? 0.0
# "Tesla is expected to report its second quarter vehicle delivery and production numbers after the bell on Thursday, and Musk’s Wednesday email suggests that Tesla hit its goals." -0.05
# https://www.cnbc.com/2020/07/01/elon-musk-congratulates-tesla-employees-ahead-of-q2-deliveries-report.html 0.0
# Leaked email last week paved the way to the latest leak apparently. 0.18333333333333335
# I don't understand why they just don't make all there internal emails available to the public. 0.13333333333333333
# https://www.thestreet.com/tesla/news/elon-musk-leaked-q2-email 0.0
# You guys watch the 60 mins where Fauci says masks are stupid and the Chinese look ridiculous for wearing them yet? -0.37777777777777777
# Are you guys still in TSLA? 0.0
# They just got featured on the watchlist at (http://tradenow.xyz) 0.0
# Ruh Roh, Covid on the rise again, so we've got to print more money! 0.625
# Thankfully though the death rate isn't going anywhere so we don't have to go back into hardcore lockdowns! 0.0
# Is Biden actually alive or is it just a weekend at bernies thing at this point ? 0.1
# If I had to choose between raising taxes or create inflation, I will vote with raising taxes. 0.0
# What about you? 0.0
# There’s only one company in the world that i can say categorically I will never buy a product from...Tesla. 0.0
# In the meantime...I’ve made more just on nvda in the past two years than you ever will in Tesla. 0.125
# I regret I didn’t take profits today! 0.0
# Now I can’t sleep again! 0.0
# How about the BLM get some money from those Nasty NETFLIX stock holders!!! -1.0
# They should PAY!!!!! 0.0
# ! 0.0
# Realistically tesla is worth more than XOM and Toyota combined. 0.4
# I haven’t bought another phone besides an iPhone since they first came out. 0.25
# I will never, ever, ever buy a Tesla anything. 0.0
#
#
#
#
# Adj Sentiment: 0.05481320848858163
# Sentiment: 0.09804717813051148

# %%
######## ARCHETECTURE ########
# dd ={'06-24-2020':
#  {'12:35':
#   {
#     'first_last_delta':'',
#     'average_sentiment':'',
#     'comments':{
#       'ID':{
#           'body':'',
#           'created_at':'',
#           'followers':'',
#           'following':'',
#           'likes':'',
#           'watchlist_stocks_count':'',
#           'join_date':'',
#           'replies':'',
#           'sentiment':'',
#           'sentiment_analysis':''
#       },
#   }
# }},
# 'last_comment':''
# }

# %%
from commentssentiment import CommentSentiment
