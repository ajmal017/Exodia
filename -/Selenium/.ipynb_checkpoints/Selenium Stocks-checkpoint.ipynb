# %%
from bs4 import BeautifulSoup
import json
import re
import time
import datetime
import os

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

#PATH = '../../../chromedriver_linux64/chromedriver'

# %%
chrome_options = Options()
chrome_options.add_argument("--headless")

# %%
PRICE = r'<span class="st_3OTz8Ec">(\d+\.\d+)</span>'
PRICE_CHANGE = r'<span class="st_19n_1MZ">(\d+\.\d+)</span>'
PRICE_CHANGE_DOLLARS = r'<span class="st_3PJUnZB">(\d+\.\d+)</span><span>'
PRICE_CHANGE_PERCENT = r'-->(\d+\.\d+)%<!--'
#COMMENTS = r'<div class="st_3SL2gug">(.*?)<div class="st_2c27B4Z st_jGV698i st_1GuPg4J st_3QTv-Ni">'
ALL_COMMENTS = r'<article class="st_VgdfbpJ">(.*?)</article>'
COMMENT_SECTION = r'<div class="st_2giLhWN st_1vC-yaI st_yCtClNI st_2mehCkH st_3PPn_WF st_DmhifDD st_2-AYUR9">(.*)<div class="st_2c27B4Z st_jGV698i st_1GuPg4J st_3QTv-Ni">'
BETWEEN_SPAN = '>(\d+\.\d+)<'

# %%
def handle_comments(HTML):
    # Regex frames
    ALL_COMMENTS = r'<article class="st_VgdfbpJ st_31oNG-n st_3A22T1e st_vmBJz6-">(.*?)</article>'
    COMMENT_SECTION = r'<div class="st_2giLhWN st_1vC-yaI st_yCtClNI st_2mehCkH st_3PPn_WF st_DmhifDD st_2-AYUR9">(.*)<div class="st_2c27B4Z st_jGV698i st_1GuPg4J st_3QTv-Ni">'
    DATE_TIME = r'<a class="st_28bQfzV st_1E79qOs st_3TuKxmZ st_3Y6ESwY st_GnnuqFp st_1VMMH6S"(.*?)<div class="st_2giLhWN st_1vC-yaI st_yCtClNI st_2mehCkH st_3PPn_WF st_DmhifDD st_2-AYUR9">'
    
    # Empty vars
    COMMENTS_LIST = []
    DATE_STAMPS = []
    SENTIMENT = []
    BULLISH = 0
    BEARISH = 0
    NEUTRAL = 0
    
    # Sentiment analysis
    for section in re.findall(ALL_COMMENTS, str(HTML)):
        if 'Bullish' in section:
            SENTIMENT += [1]
        elif 'Bearish' in section:
            SENTIMENT += [-1]
        else:
            SENTIMENT += [0]
                        
        # Collect comments text
        comment = re.search(COMMENT_SECTION,section).group()
        date = re.search(DATE_TIME,section).group()
        
        
        COMMENTS_LIST += [BeautifulSoup(comment).get_text()]
        DATE_STAMPS += [BeautifulSoup('<a '+date).get_text()]
        
        
    # Parse times
    FORMATTED_TIMES = []
    count = 0
    for tim in DATE_STAMPS:
        if 'PM' in tim or 'AM' in tim:
            break
        elif tim == 'now':
            FORMATTED_TIMES += [datetime.datetime.fromtimestamp(time.time()).strftime("%H:%M:%S.%f")]
        else:
            t = int(tim[0:-1])
            if t < 21:
                FORMATTED_TIMES += [datetime.datetime.fromtimestamp(time.time()-t*60).strftime("%H:%M:%S.%f")]
            else:
                break
        count += 1
    
    for i in SENTIMENT[0:count]:
        if i == 1:
            BULLISH += 1
        elif i == -1:
            BEARISH += 1
        else:
            NEUTRAL += 1
    
    print(f'Bullish: {BULLISH}\nBearish: {BEARISH}\nNeutral: {NEUTRAL}')
    COMMENTS = {FORMATTED_TIMES[i]:{"text":COMMENTS_LIST[i],"sentiment":SENTIMENT[i]} for i in range(len(FORMATTED_TIMES))}
    SENTIMENT = {"bullish":BULLISH,"bearish":BEARISH,"neutral":NEUTRAL}
    
    return(COMMENTS,SENTIMENT)

# %%
def handle_json(HTML):
    # Regex frame
    JSON_PARSE = r'"symbol":(.*)}},"isFetching"'
    
    # Scrape for frame
    raw_json = re.search(JSON_PARSE, str(HTML)).group()
    
    # Format text to JSON
    JSON_TXT = raw_json
    JSON_TXT = JSON_TXT.replace('},"isFetching"','')
    BODY = JSON_TXT.split(",")[4:]
    TXT = ",".join(BODY)
    JSON_TXT = '{'+TXT
    
    # JSON loads
    TICKER_DATA = json.loads(JSON_TXT)
    
    return(TICKER_DATA)

# %%
def push_json_to_csv(JSON,COMMENTS,SENTIMENT,MKTCAP,RATIO,RELATIVE_RATIO,SYMBOL):
    # SENTIMENT = (BULLS-BEARS)/NEUTRAL
    
    globalMetrics = [
        'open',
        'previousClose',
    ]
    
    constMetrics = [
        'trendingScore',
        'trending', #True/False
        'volume',
        'volumeChange',
        'watchlistCount',
        'low',
        'high',
        'price',
        'change',
        'percentChange',
        #'exchange',
        #'id',
        #'previousCloseDate',
        #'lastUpdated', #MM/DD/YYYY, HH:MM:SS AM/PM EDT
    ]

    
    symbol = SYMBOL
    DATE = str(datetime.datetime.now()).split('.')[0].split(' ')[0]
    TIME = str(datetime.datetime.now()).split('.')[0].split(' ')[1][0:-3]
    
    if os.path.isfile(f'stock/{symbol}.json') != True:
        with open(f'stock/{symbol}.json','w') as f:
            json.dump({symbol:{"date":{DATE:{"open": "", "previousClose": "", TIME:{"relativeRatio":"", "ratio":"", "mktcap":"", "comments": {}, "sentiment": {}, "trendingScore": "", "trending": "", "volume": "", "relativeVolume":"", "volumeChange": "", "watchlistCount": "", "low": "", "high": "", "price": "", "change": "", "percentChange":""}}}}}, f)
        
    with open(f'stock/{symbol}.json','r+') as f:
        DATA = json.load(f)
    
    try:
        TODAY_DATA = DATA[symbol]["date"][DATE].copy()
    except:
        TODAY_FRAME = {DATE:{"open": "", "previousClose": ""}}
        DATA[symbol]["date"].update(TODAY_FRAME)
        TODAY_DATA = DATA[symbol]["date"][DATE].copy()
        
    CURRENT_DATA = {"relativeRatio":"", "ratio":"", "mktcap":"", "comments": {}, "sentiment": {}, "trendingScore": "", "trending": "", "volume": "", "relativeVolume":"", "volumeChange": "", "watchlistCount": "", "low": "", "high": "", "price": "", "change": "", "percentChange":""}
                
    for metr in constMetrics:
        CURRENT_DATA[metr] = JSON[metr]
        
    for metr in globalMetrics:
        TODAY_DATA.update({metr:JSON[metr]})
    
    RELATIVE_VOLUME = get_relative_volume(int(JSON["volume"]))
    CURRENT_DATA.update({"relativeVolume":RELATIVE_VOLUME})
    CURRENT_DATA.update({"ratio":RATIO})
    CURRENT_DATA.update({"relativeRatio":RELATIVE_RATIO})
    CURRENT_DATA.update({"mktcap":MKTCAP})
    CURRENT_DATA.update({"comments":COMMENTS})
    CURRENT_DATA.update({"sentiment":SENTIMENT})
        
    TODAY_DATA.update({TIME:CURRENT_DATA})
    DATA[symbol]["date"][DATE] = TODAY_DATA
    with open(f'stock/{symbol}.json','w') as f:
        json.dump(DATA, f)

# %%
from yahoo_fin import stock_info as si
# si.get_day_gainers()
# si.get_day_losers()

def get_mktcap_ratio(symbol):
    MKTCAP_DICT = {'K':1000,'M':1000000,'B':1000000000,'T':1000000000000}
    DATA = si.get_quote_table(symbol, dict_result=True)
    MKTCAP = float(DATA['Market Cap'][:-1])*MKTCAP_DICT[DATA['Market Cap'][-1]]
    VOLUME = float(DATA['Volume'])
    RELATIVE_VOLUME = get_relative_volume(int(VOLUME))
    PRICE  = float(DATA['Quote Price'])
    
    
    # Ratio = 1 / ((MktCap / Price) / volume)
    NUM_SHARES = MKTCAP/PRICE
    RATIO = 1 / (NUM_SHARES/VOLUME)
    RELATIVE_RATIO = 1 / (NUM_SHARES/RELATIVE_VOLUME)
    
    return(MKTCAP,RATIO,RELATIVE_RATIO)

# %%
def get_relative_volume(volume):
    DATE = str(datetime.datetime.now()).split('.')[0].split(' ')[0]
    TIME = str(datetime.datetime.now()).split('.')[0].split(' ')[1][0:-3]
    
    HOUR = int(TIME[0:2])
    MIN = int(TIME[3:5])
    
    if HOUR < 9 or HOUR > 20:
        return volume
    elif HOUR < 9 and MIN < 30:
        return volume
    else:
        ELAPSED = (HOUR*3+int(MIN/20))-(9*3+1.5)
        return volume/ELAPSED

# %%
t = time.time()
driver = webdriver.Chrome(ChromeDriverManager().install(),options=chrome_options)
SYMBOL = 'LK'
driver.get(f'https://stocktwits.com/symbol/{SYMBOL}')
Y = 10000
driver.execute_script(f"window.scrollTo(0, {Y})") 
last_height = driver.execute_script("return document.body.scrollHeight")

HTML = driver.page_source.encode("utf-8")
driver.quit()
print(time.time()-t)
# Out:
# [WDM] - Cache is valid for [04/06/2020]
# [WDM] - Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# [WDM] - Driver found in cache [/home/lukepiette/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
# 6.982551097869873

# %%
def cycle_data(tim,SYMBOLS=[]):
    Y = 10000
    for i in range(tim):
        driver = webdriver.Chrome(ChromeDriverManager().install(),options=chrome_options)
        for symb in SYMBOLS:
            print(symb)
            t = time.time()
            driver.get(f'https://stocktwits.com/symbol/{symb}')
            driver.execute_script(f"window.scrollTo(0, {Y})") 
            #last_height = driver.execute_script("return document.body.scrollHeight")

            HTML = driver.page_source.encode("utf-8")

            JSON = handle_json(HTML)
            COMMENTS,SENTIMENT = handle_comments(HTML)
            MKTCAP,RATIO,RELATIVE_RATIO = get_mktcap_ratio(symb)
            push_json_to_csv(JSON,COMMENTS,SENTIMENT,MKTCAP,RATIO,RELATIVE_RATIO,symb)
            
            print(f'{symb} done in {time.time()-t}\n')

        driver.quit()
        print('Sleeping...\n')
        time.sleep(20*60)

# %%
SYMBOLS = ['LK','XSPA','PRTY','HTZ']
cycle_data(2,SYMBOLS=SYMBOLS)
# Out:
# [WDM] - Cache is valid for [04/06/2020]
# [WDM] - Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# [WDM] - Driver found in cache [/home/lukepiette/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
# LK
# Bullish: 10
# Bearish: 1
# Neutral: 9
# LK done in 13.189904689788818
#
# XSPA
# Bullish: 9
# Bearish: 0
# Neutral: 11
# XSPA done in 5.438066244125366
#
# PRTY
# Bullish: 3
# Bearish: 0
# Neutral: 0
# PRTY done in 5.004659414291382
#
# HTZ
# Bullish: 12
# Bearish: 2
# Neutral: 6
# HTZ done in 4.9756019115448
#
# Sleeping...

# %%
with open(f'stock/{SYMBOL}.json','r') as f:
    parsed = json.load(f)
    print(json.dumps(parsed, indent=2, sort_keys=False))
# Out:
# {
#   "LK": {
#     "date": {
#       "2020-06-03": {
#         "open": 2.39,
#         "previousClose": 2.33,
#         "20:30": {
#           "ratio": 0.20586066279513288,
#           "mktcap": 653119000.0,
#           "comments": {
#             "20:28:59.601105": {
#               "text": "$LK we going to 3$",
#               "sentiment": 1
#             },
#             "20:23:59.601138": {
#               "text": "$LK I know patience is wearying thin, but those who stay will nor be kicking themselves later, aka barstool founder finding out he missed out on MARK today, after selling 2 mil yesterday.\\n\\nLK will drop it like it\\xe2\\x80\\x99s hot all at once and it will be like Christmas and New Years.\\n\\nThis is what missing out looks like.\\ntwitter.com/stoolpresidente...",
#               "sentiment": 0
#             },
#             "20:20:59.601150": {
#               "text": "$LK TD shows it at 2.63",
#               "sentiment": 0
#             },
#             "20:18:59.601156": {
#               "text": "$LK OK, I\\xe2\\x80\\x99ve kept a close eye on  this stock since it\\xe2\\x80\\x99s downfall. My philosophy toward this stock is: keep it simple stupid! We live in a world of forgiveness and understanding. Why punish the many because of the few. A world of 2nd chances. LK will get their second chance. Like it or not. Bullish or Bearish. America or China. Believe it or not, the majority of this world is made up of outstanding citizens. The media just likes to show all the bad in our world, which is less than 8%. \\n\\nOpen your mind up. Take a few deep breaths. Relax. Then make your decision. Yes, this is just my opinion. But I hope it makes you give some serious thought, into,  taking an opportunity of a life time. GLTA. I\\xe2\\x80\\x99ve already been blessed.",
#               "sentiment": 1
#             },
#             "20:17:59.601161": {
#               "text": "$LK not convinced yet this is very volatile and could drop fast again.",
#               "sentiment": 0
#             },
#             "20:17:59.601166": {
#               "text": "$LK tomorrow we see $3 at least",
#               "sentiment": 1
#             },
#             "20:14:59.601172": {
#               "text": "$LK  bears: help I\\xe2\\x80\\x99ve fallen and can\\xe2\\x80\\x99t get up! Bulls: stfu and stay down!",
#               "sentiment": 1
#             },
#             "20:13:59.601177": {
#               "text": "$LK slow and steady people. Uptrend continues. Hold ur poker hand. Shorts don\\xe2\\x80\\x99t even have a pair. Lol. They have no choice but to raise it slowly. Patience.",
#               "sentiment": 1
#             },
#             "20:12:59.601182": {
#               "text": "$LK  Just kidding",
#               "sentiment": 0
#             },
#             "20:11:59.601187": {
#               "text": "$LK \\xf0\\x9f\\xa4\\x91",
#               "sentiment": 1
#             },
#             "20:10:59.601192": {
#               "text": "$TMBR $LK LET\\'S GO!!!! TOMORROW IS GOING TO BE CRAZY!!!",
#               "sentiment": 1
#             }
#           },
#           "sentiment": {
#             "bullish": 22,
#             "bearish": 2,
#             "neutral": 16
#           },
#           "trendingScore": -0.245762,
#           "trending": false,
#           "volume": 52112990,
#           "volumeChange": -22.45,
#           "watchlistCount": 30434,
#           "low": 2.37,
#           "high": 2.68,
#           "price": 2.63,
#           "change": 0.3,
#           "percentChange": 12.668000000000001
#         }
#       },
#       "2020-06-04": {
#         "open": 131.35,
#         "previousClose": 132.84,
#         "10:38": {
#           "ratio": 0.15059902882941067,
#           "mktcap": 790072000.0,
#           "comments": {
#             "10:38:26.761435": {
#               "text": "$LK got in this at 2.21, we good. It\\xe2\\x80\\x99s got a lot of room up top.",
#               "sentiment": 1
#             },
#             "10:38:26.761466": {
#               "text": "$LK no reason this shouldn\\xe2\\x80\\x99t be around $6-7",
#               "sentiment": 1
#             },
#             "10:38:26.761473": {
#               "text": "$LK bullrun is over, sell now",
#               "sentiment": -1
#             },
#             "10:38:26.761478": {
#               "text": "$LK IM NOT FUCKIN LUCKIN SELLING.\\n\\nBye shorts \\xf0\\x9f\\x98\\x82\\xf0\\x9f\\x98\\x82\\xf0\\x9f\\x96\\x95\\xf0\\x9f\\x8f\\xbc\\xf0\\x9f\\x96\\x95\\xf0\\x9f\\x8f\\xbc\\xf0\\x9f\\x96\\x95\\xf0\\x9f\\x8f\\xbc",
#               "sentiment": 1
#             },
#             "10:38:26.761482": {
#               "text": "$LK glad I didn\\xe2\\x80\\x99t go into $GNUS and went all in $LK bless up!!",
#               "sentiment": 1
#             },
#             "10:38:26.761487": {
#               "text": "$LK keep on truckin\\' !",
#               "sentiment": 1
#             },
#             "10:37:26.761496": {
#               "text": "$LK  weak hands selling. SMFH all u gotta do is wait man wait. just like a landlord who waits a month u can also wait. shit relax.",
#               "sentiment": 1
#             },
#             "10:37:26.761502": {
#               "text": "$LK  up up up baby.  Enjoy the ride to the Moon.",
#               "sentiment": 0
#             },
#             "10:37:26.761507": {
#               "text": "$LK The writing is on the wall",
#               "sentiment": 0
#             },
#             "10:37:26.761512": {
#               "text": "$LK buy any dip",
#               "sentiment": 1
#             },
#             "10:37:26.761517": {
#               "text": "$LK Step by Step towards 4$+",
#               "sentiment": 1
#             },
#             "10:37:26.761521": {
#               "text": "$LK What was the story with the scam or whatever ? can\\'t find anything ? I\\'m in at 2.6 so happy with it",
#               "sentiment": 0
#             },
#             "10:37:26.761526": {
#               "text": "$LK patience paying off for me here! $ATOS is the next one to blast off! FDA approval anyday now! 6.00+",
#               "sentiment": 1
#             },
#             "10:37:26.761531": {
#               "text": "$LK I dont have a huge position yet but if it even pumps to $7 ill be looking at a free apple watch, courtesy of Luckin :)",
#               "sentiment": 1
#             },
#             "10:37:26.761535": {
#               "text": "$LK Chinese coffee matters",
#               "sentiment": 0
#             },
#             "10:36:26.761541": {
#               "text": "$LK click clack.",
#               "sentiment": 1
#             },
#             "10:36:26.761545": {
#               "text": "$LK Thank you bears once again.",
#               "sentiment": 1
#             },
#             "10:36:26.761550": {
#               "text": "$LK should continue to squeeze into the weekend\\xf0\\x9f\\x92\\xaa",
#               "sentiment": 1
#             },
#             "10:36:26.761555": {
#               "text": "$LK still cheap IPO was at 17, and most certainly is not a pump and dump. They have 6900+ storefronts in China",
#               "sentiment": 1
#             },
#             "10:36:26.761560": {
#               "text": "$LK damnnnn, glad i switched camps, looks like the gaps will be filled!",
#               "sentiment": 1
#             },
#             "10:36:26.761564": {
#               "text": "$LK even wont sell it for 5 Dollars xdxd",
#               "sentiment": 1
#             },
#             "10:36:26.761569": {
#               "text": "$LK finally breaking even! This should go back to regular trading prices if ER and financial paperwork is positive.",
#               "sentiment": 0
#             },
#             "10:36:26.761574": {
#               "text": "$LK I was hoping for $3.20 by the end of the week.  Adjusting now to to hit $3.45 by the end of the week.  Crazy gains.  I guess this happens when a stock loses 90% of its value.  Only way is up.",
#               "sentiment": 1
#             },
#             "10:36:26.761578": {
#               "text": "$LK looking pretty clear to 4.00! In since 2.07!",
#               "sentiment": 1
#             },
#             "10:36:26.761583": {
#               "text": "$LK Everyone loves a little Chinese fraud in their life",
#               "sentiment": 1
#             },
#             "10:36:26.761588": {
#               "text": "$LK and the squeeeze is on!!",
#               "sentiment": 1
#             },
#             "10:36:26.761593": {
#               "text": "$LK ok where and  is the buy in to be in the know on a this manipulated shit im getting a little tired ;)",
#               "sentiment": 1
#             },
#             "10:35:26.761597": {
#               "text": "$LK averaged up",
#               "sentiment": 1
#             },
#             "10:35:26.761602": {
#               "text": "$LK SHORT SQEEZE",
#               "sentiment": 1
#             },
#             "10:35:26.761607": {
#               "text": "$LK Hold Bulls!!!",
#               "sentiment": 1
#             },
#             "10:35:26.761611": {
#               "text": "$LK 3.2!!!!!! Absolutely no reason with this volume islt cant hit $4 \\xf0\\x9f\\x98\\xb3 shorts have to cover soon",
#               "sentiment": 0
#             },
#             "10:35:26.761616": {
#               "text": "$LK See you guys at $30. This will stay on the NASDAQ.",
#               "sentiment": 1
#             },
#             "10:35:26.761621": {
#               "text": "$LK don\\xe2\\x80\\x99t miss the boat when this bad boy is over $5 today and 10$ end of month",
#               "sentiment": 1
#             },
#             "10:35:26.761625": {
#               "text": "$LK congrats long.  I\\xe2\\x80\\x99m out and will buy in after the afternoon fade if I get it.",
#               "sentiment": 1
#             },
#             "10:35:26.761630": {
#               "text": "$LK IPO @ $17 w/ 2300 stores now add 4,000 stores (total store count nearing 7,000)  -300mil (not so bad will have a few bad apples when moving that fast). china coffee consumers on the rise in a big way. Lukin app is number 4 most used /downloaded in china. you Do the math!",
#               "sentiment": 1
#             },
#             "10:35:26.761635": {
#               "text": "$LK New High: 0.01. Next resistance 3.49 from 5/20/2020",
#               "sentiment": 0
#             },
#             "10:35:26.761639": {
#               "text": "$LK on the way back to 50.00 !!!!",
#               "sentiment": 1
#             },
#             "10:34:26.761644": {
#               "text": "$LK nice flag breakup above our resistance. If this keeps up .... we will call the kraken \\xf0\\x9f\\x92\\xa5\\xf0\\x9f\\x9a\\x80\\xf0\\x9f\\x92\\xb0",
#               "sentiment": 1
#             },
#             "10:34:26.761649": {
#               "text": "$LK \\nNot Selling A Share Shorties \\nWay up to 5 \\xf0\\x9f\\x9a\\x80\\xf0\\x9f\\x9a\\x80\\xf0\\x9f\\x9a\\x80",
#               "sentiment": 1
#             }
#           },
#           "sentiment": {
#             "bullish": 31,
#             "bearish": 1,
#             "neutral": 7
#           },
#           "trendingScore": 6.24678,
#           "trending": false,
#           "volume": 30085555,
#           "volumeChange": -18.03,
#           "watchlistCount": 30658,
#           "low": 2.7,
#           "high": 3.22,
#           "price": 3.16,
#           "change": 0.58,
#           "percentChange": 22.481
#         },
#         "10:40": {
#           "ratio": 0.15267408213350156,
#           "mktcap": 794882000.0,
#           "comments": {
#             "10:40:34.673422": {
#               "text": "$LK 2500 shares now!",
#               "sentiment": 0
#             },
#             "10:40:34.673461": {
#               "text": "$LK are ya lucking kidding me!!! $5 incoming today maybe higher!!!",
#               "sentiment": 1
#             },
#             "10:40:34.673468": {
#               "text": "$LK",
#               "sentiment": 1
#             },
#             "10:40:34.673473": {
#               "text": "$LK I gotin PM for a trade . But I\\xe2\\x80\\x99m trying to put a valuation on this until the fraud smoke clears. Any quick hits on why this took off this week?",
#               "sentiment": 0
#             },
#             "10:40:34.673478": {
#               "text": "$LK $3 is the new $2...the powers that be don\\xe2\\x80\\x99t want it under that.",
#               "sentiment": 1
#             },
#             "10:39:34.673486": {
#               "text": "$LK",
#               "sentiment": 1
#             },
#             "10:39:34.673492": {
#               "text": "$LK setting sell limits to $25 by end of month",
#               "sentiment": 1
#             },
#             "10:39:34.673498": {
#               "text": "$LK hope we remember we are not a $3 stock, let\\xe2\\x80\\x99s wait till $10 atleast",
#               "sentiment": 1
#             },
#             "10:39:34.673503": {
#               "text": "Bullish Trades: $AAL $NIO $LK $PRMW $DFEN \\nTrading Strategies: Long, Call Writing and Put Selling\\n\\n#StockToWatch #StockToTrade #StockMarket #Investing #StockTrading #StockNews",
#               "sentiment": 1
#             },
#             "10:39:34.673508": {
#               "text": "$LK \\nI think we are just getting started.",
#               "sentiment": 0
#             },
#             "10:38:34.673513": {
#               "text": "$LK i rarely make comments about shorting but in this case, it\\xe2\\x80\\x99s very risky to be short",
#               "sentiment": 0
#             },
#             "10:38:34.673518": {
#               "text": "$LK you guys think it\\xe2\\x80\\x99s gonna dip again?",
#               "sentiment": 0
#             },
#             "10:38:34.673523": {
#               "text": "$LK got in this at 2.21, we good. It\\xe2\\x80\\x99s got a lot of room up top.",
#               "sentiment": 1
#             },
#             "10:38:34.673527": {
#               "text": "$LK as long as we consolidate $3 until close that will do us. Earnings will push us even higher mark my words, we are not a $3 stock even with what\\xe2\\x80\\x99s went on",
#               "sentiment": 1
#             },
#             "10:38:34.673532": {
#               "text": "$LK no reason this shouldn\\xe2\\x80\\x99t be around $6-7",
#               "sentiment": 1
#             },
#             "10:37:34.673537": {
#               "text": "$LK bullrun is over, sell now",
#               "sentiment": -1
#             },
#             "10:37:34.673543": {
#               "text": "$LK IM NOT FUCKIN LUCKIN SELLING.\\n\\nBye shorts \\xf0\\x9f\\x98\\x82\\xf0\\x9f\\x98\\x82\\xf0\\x9f\\x96\\x95\\xf0\\x9f\\x8f\\xbc\\xf0\\x9f\\x96\\x95\\xf0\\x9f\\x8f\\xbc\\xf0\\x9f\\x96\\x95\\xf0\\x9f\\x8f\\xbc",
#               "sentiment": 1
#             },
#             "10:37:34.673548": {
#               "text": "$LK glad I didn\\xe2\\x80\\x99t go into $GNUS and went all in $LK bless up!!",
#               "sentiment": 1
#             },
#             "10:37:34.673553": {
#               "text": "$LK keep on truckin\\' !",
#               "sentiment": 1
#             },
#             "10:37:34.673558": {
#               "text": "$LK  weak hands selling. SMFH all u gotta do is wait man wait. just like a landlord who waits a month u can also wait. shit relax.",
#               "sentiment": 1
#             }
#           },
#           "sentiment": {
#             "bullish": 14,
#             "bearish": 1,
#             "neutral": 5
#           },
#           "trendingScore": 6.24678,
#           "trending": false,
#           "volume": 31490627,
#           "volumeChange": -18.03,
#           "watchlistCount": 30658,
#           "low": 2.7,
#           "high": 3.22,
#           "price": 3.13,
#           "change": 0.55,
#           "percentChange": 21.318
#         },
#         "10:41": {
#           "ratio": 0.1532211972134741,
#           "mktcap": 797160000.0,
#           "comments": {
#             "10:40:59.532828": {
#               "text": "$LK Does anyone knows when LK has hearing date with NASDAQ?",
#               "sentiment": 1
#             },
#             "10:40:59.532872": {
#               "text": "$LK the big boys walked it down... loaded up already... and will see that it gets back to it\\xe2\\x80\\x99s true value",
#               "sentiment": 0
#             },
#             "10:40:59.532880": {
#               "text": "$LK buy buy buy !!",
#               "sentiment": 1
#             },
#             "10:40:59.532885": {
#               "text": "$LK @JohnBi0 @Escobar_Dollars \\xf0\\x9f\\x8d\\xba\\xf0\\x9f\\x8d\\xbb we did it boys",
#               "sentiment": 1
#             },
#             "10:40:59.532889": {
#               "text": "$LK 2500 shares now!",
#               "sentiment": 0
#             },
#             "10:39:59.532896": {
#               "text": "$LK are ya lucking kidding me!!! $5 incoming today maybe higher!!!",
#               "sentiment": 1
#             },
#             "10:39:59.532903": {
#               "text": "$LK I gotin PM for a trade . But I\\xe2\\x80\\x99m trying to put a valuation on this until the fraud smoke clears. Any quick hits on why this took off this week?",
#               "sentiment": 0
#             },
#             "10:39:59.532907": {
#               "text": "$LK $3 is the new $2...the powers that be don\\xe2\\x80\\x99t want it under that.",
#               "sentiment": 1
#             },
#             "10:39:59.532912": {
#               "text": "$LK",
#               "sentiment": 1
#             },
#             "10:39:59.532917": {
#               "text": "$LK setting sell limits to $25 by end of month",
#               "sentiment": 1
#             },
#             "10:39:59.532922": {
#               "text": "$LK hope we remember we are not a $3 stock, let\\xe2\\x80\\x99s wait till $10 atleast",
#               "sentiment": 1
#             },
#             "10:39:59.532926": {
#               "text": "Bullish Trades: $AAL $NIO $LK $PRMW $DFEN \\nTrading Strategies: Long, Call Writing and Put Selling\\n\\n#StockToWatch #StockToTrade #StockMarket #Investing #StockTrading #StockNews",
#               "sentiment": 1
#             },
#             "10:39:59.532931": {
#               "text": "$LK \\nI think we are just getting started.",
#               "sentiment": 0
#             },
#             "10:38:59.532935": {
#               "text": "$LK i rarely make comments about shorting but in this case, it\\xe2\\x80\\x99s very risky to be short",
#               "sentiment": 0
#             },
#             "10:38:59.532940": {
#               "text": "$LK you guys think it\\xe2\\x80\\x99s gonna dip again?",
#               "sentiment": 0
#             },
#             "10:37:59.532945": {
#               "text": "$LK got in this at 2.21, we good. It\\xe2\\x80\\x99s got a lot of room up top.",
#               "sentiment": 1
#             },
#             "10:37:59.532949": {
#               "text": "$LK as long as we consolidate $3 until close that will do us. Earnings will push us even higher mark my words, we are not a $3 stock even with what\\xe2\\x80\\x99s went on",
#               "sentiment": 1
#             },
#             "10:37:59.532954": {
#               "text": "$LK no reason this shouldn\\xe2\\x80\\x99t be around $6-7",
#               "sentiment": 1
#             },
#             "10:37:59.532959": {
#               "text": "$LK bullrun is over, sell now",
#               "sentiment": -1
#             },
#             "10:37:59.532963": {
#               "text": "$LK IM NOT FUCKIN LUCKIN SELLING.\\n\\nBye shorts \\xf0\\x9f\\x98\\x82\\xf0\\x9f\\x98\\x82\\xf0\\x9f\\x96\\x95\\xf0\\x9f\\x8f\\xbc\\xf0\\x9f\\x96\\x95\\xf0\\x9f\\x8f\\xbc\\xf0\\x9f\\x96\\x95\\xf0\\x9f\\x8f\\xbc",
#               "sentiment": 1
#             },
#             "10:37:59.532967": {
#               "text": "$LK glad I didn\\xe2\\x80\\x99t go into $GNUS and went all in $LK bless up!!",
#               "sentiment": 1
#             },
#             "10:37:59.532972": {
#               "text": "$LK keep on truckin\\' !",
#               "sentiment": 1
#             },
#             "10:36:59.532976": {
#               "text": "$LK  weak hands selling. SMFH all u gotta do is wait man wait. just like a landlord who waits a month u can also wait. shit relax.",
#               "sentiment": 1
#             },
#             "10:36:59.532981": {
#               "text": "$LK  up up up baby.  Enjoy the ride to the Moon.",
#               "sentiment": 0
#             },
#             "10:36:59.532985": {
#               "text": "$LK The writing is on the wall",
#               "sentiment": 0
#             },
#             "10:36:59.532990": {
#               "text": "$LK buy any dip",
#               "sentiment": 1
#             },
#             "10:36:59.533006": {
#               "text": "$LK Step by Step towards 4$+",
#               "sentiment": 1
#             },
#             "10:36:59.533014": {
#               "text": "$LK What was the story with the scam or whatever ? can\\'t find anything ? I\\'m in at 2.6 so happy with it",
#               "sentiment": 0
#             },
#             "10:36:59.533018": {
#               "text": "$LK patience paying off for me here! $ATOS is the next one to blast off! FDA approval anyday now! 6.00+",
#               "sentiment": 1
#             },
#             "10:36:59.533023": {
#               "text": "$LK I dont have a huge position yet but if it even pumps to $7 ill be looking at a free apple watch, courtesy of Luckin :)",
#               "sentiment": 1
#             },
#             "10:36:59.533027": {
#               "text": "$LK Chinese coffee matters",
#               "sentiment": 0
#             },
#             "10:35:59.533032": {
#               "text": "$LK click clack.",
#               "sentiment": 1
#             },
#             "10:35:59.533037": {
#               "text": "$LK Thank you bears once again.",
#               "sentiment": 1
#             },
#             "10:35:59.533041": {
#               "text": "$LK should continue to squeeze into the weekend\\xf0\\x9f\\x92\\xaa",
#               "sentiment": 1
#             },
#             "10:35:59.533046": {
#               "text": "$LK still cheap IPO was at 17, and most certainly is not a pump and dump. They have 6900+ storefronts in China",
#               "sentiment": 1
#             },
#             "10:35:59.533050": {
#               "text": "$LK damnnnn, glad i switched camps, looks like the gaps will be filled!",
#               "sentiment": 1
#             },
#             "10:35:59.533055": {
#               "text": "$LK even wont sell it for 5 Dollars xdxd",
#               "sentiment": 1
#             },
#             "10:35:59.533060": {
#               "text": "$LK finally breaking even! This should go back to regular trading prices if ER and financial paperwork is positive.",
#               "sentiment": 0
#             },
#             "10:35:59.533064": {
#               "text": "$LK I was hoping for $3.20 by the end of the week.  Adjusting now to to hit $3.45 by the end of the week.  Crazy gains.  I guess this happens when a stock loses 90% of its value.  Only way is up.",
#               "sentiment": 1
#             }
#           },
#           "sentiment": {
#             "bullish": 27,
#             "bearish": 1,
#             "neutral": 11
#           },
#           "trendingScore": 6.24678,
#           "trending": false,
#           "volume": 32051951,
#           "volumeChange": -18.03,
#           "watchlistCount": 30658,
#           "low": 2.7,
#           "high": 3.22,
#           "price": 3.14,
#           "change": 0.56,
#           "percentChange": 21.705
#         },
#         "10:45": {
#           "ratio": 0.15896505633722524,
#           "mktcap": 817412000.0,
#           "comments": {
#             "10:45:50.872868": {
#               "text": "$LK lol not a Panna stock",
#               "sentiment": 1
#             },
#             "10:45:50.872906": {
#               "text": "$LK lol shorts got burned \\xf0\\x9f\\xa4\\xa3\\xf0\\x9f\\xa4\\xa3\\xf0\\x9f\\xa4\\xa3\\xf0\\x9f\\xa4\\xa3\\xf0\\x9f\\xa4\\xa3 t0 bad I missed out. Sold out yesterday, funds wont clear until tomorrow...I knew this would happen",
#               "sentiment": 1
#             },
#             "10:45:50.872913": {
#               "text": "$LK Crossed above resistance, 3.20.  Time: 12 minutes 33 seconds.  Volume: 5,149,659.",
#               "sentiment": 0
#             },
#             "10:45:50.872917": {
#               "text": "$LK (((( BREAKOUT !!! )))) \\xf0\\x9f\\x9a\\x80\\xf0\\x9f\\x92\\xaf",
#               "sentiment": 1
#             },
#             "10:45:50.872922": {
#               "text": "$LK f**k me baby that\\'s what she said \\xf0\\x9f\\xa4\\xa6\\xf0\\x9f\\x8f\\xbb\\xe2\\x80\\x8d\\xe2\\x99\\x82\\xef\\xb8\\x8f\\xf0\\x9f\\x98\\x86\\xf0\\x9f\\x98\\x86\\xf0\\x9f\\x98\\x86",
#               "sentiment": 0
#             },
#             "10:45:50.872926": {
#               "text": "$LK anyone knows what happen to Gnus to drop?",
#               "sentiment": 0
#             },
#             "10:45:50.872931": {
#               "text": "$LK 4th most downloaded app in food category.",
#               "sentiment": 1
#             },
#             "10:45:50.872935": {
#               "text": "$LK  last weeks convo with our buddy @dolphinblue Jack my brotha I hope you took my advice!",
#               "sentiment": 1
#             },
#             "10:44:50.872941": {
#               "text": "$LK You either 10x your money here in a couple months or you lose everything.. God I love it.. casinos don\\xe2\\x80\\x99t even give you those odds lets roll \\xf0\\x9f\\x8e\\xb2\\xf0\\x9f\\x8e\\xb0",
#               "sentiment": 1
#             },
#             "10:44:50.872948": {
#               "text": "$LK many people made fun and laughed at me when I told them im going to invest in Lucking at 2.10. No one laughing now haha \\xf0\\x9f\\x99\\x83\\xf0\\x9f\\x90\\x89",
#               "sentiment": 1
#             },
#             "10:44:50.872953": {
#               "text": "$ITRM red to GREEN move soon IMO (traded 5 last week and 6) oversold my $LK took time but look now \\xf0\\x9f\\x99\\x8f\\xf0\\x9f\\x8f\\xbd\\xf0\\x9f\\x8f\\x83\\xf0\\x9f\\x91\\x88\\xf0\\x9f\\x8f\\xbd",
#               "sentiment": 1
#             },
#             "10:44:50.872957": {
#               "text": "$LK FOMO soon",
#               "sentiment": 1
#             },
#             "10:44:50.872962": {
#               "text": "$LK congrats to some of us that are slowly untrapping our falling knife funds\\xf0\\x9f\\x98\\x82\\xf0\\x9f\\x98\\x82\\xf0\\x9f\\x98\\x82",
#               "sentiment": 1
#             },
#             "10:44:50.872967": {
#               "text": "$LK To many happy Bulls. Bubble bursting is coming. You have to be a buyer when it\\'s red. That way you have made that .58 cents. Now you are all chasing castles. A recipe for pain.",
#               "sentiment": 0
#             },
#             "10:44:50.872972": {
#               "text": "$LK sold at 2.97, I wish I woulbe  just stayed asleep But since my wife also works from home, she hits me and makes me do chores.",
#               "sentiment": 0
#             },
#             "10:44:50.872976": {
#               "text": "$LK  this is a stock tinderbox waiting for that ER and new guidance . Once out it\\xe2\\x80\\x99s off to races . And if BO rumors spring up it\\xe2\\x80\\x99s a wild fire",
#               "sentiment": 0
#             },
#             "10:44:50.872981": {
#               "text": "$LK still shocked how much of a bargain these share prices are. Can\\xe2\\x80\\x99t believe I got in",
#               "sentiment": 1
#             },
#             "10:44:50.872986": {
#               "text": "$TMDI $LK $HLX Make  big  profits  with  us. Everyone should  join  this  room  for  good results.  Free  check  out  here!\\n\\nstocktwits.com/EusebiaGunne...",
#               "sentiment": 0
#             },
#             "10:43:50.872990": {
#               "text": "$LK $4 coming today!\\xf0\\x9f\\xa4\\x99\\xf0\\x9f\\x8f\\xbd",
#               "sentiment": 1
#             },
#             "10:43:50.873010": {
#               "text": "$LK if you were smart and shorted this a couple of weeks ago at the reopening of the stock and didn\\xe2\\x80\\x99t cover the 4 times they tried to take it below $2, you\\xe2\\x80\\x99re an IDIOT!\\xf0\\x9f\\x98\\x82",
#               "sentiment": 1
#             },
#             "10:42:50.873020": {
#               "text": "$LK Congrats you Luck-in Bastards!",
#               "sentiment": 1
#             },
#             "10:42:50.873025": {
#               "text": "$GNUS $CIDM $XSPA $LK $AAL Hey all of mate!! lf you really want to make a huge profit on stock trading. Then this com.munity is for you!! stocktwits.com/usatrade32/m...",
#               "sentiment": 1
#             },
#             "10:42:50.873030": {
#               "text": "$LK easy $10 really soon",
#               "sentiment": 1
#             },
#             "10:42:50.873035": {
#               "text": "$GNUS thats what happens when u chase overbought stocks i was in gnus at .40 in 5/6/2020! Now im in $LK at 2.45 and it is still oversold ! $SPY $XSPA $CIDM",
#               "sentiment": 1
#             },
#             "10:42:50.873039": {
#               "text": "$LK imagine shorting a 50 dollar stock when its at 2 dollars lol",
#               "sentiment": 0
#             },
#             "10:41:50.873044": {
#               "text": "$LK Congrats to the strong hands. \\n\\nWhats the chances this gets delisted?  What\\xe2\\x80\\x99s the real numbers?",
#               "sentiment": 0
#             },
#             "10:40:50.873049": {
#               "text": "$LK Does anyone knows when LK has hearing date with NASDAQ?",
#               "sentiment": 1
#             },
#             "10:40:50.873054": {
#               "text": "$LK the big boys walked it down... loaded up already... and will see that it gets back to it\\xe2\\x80\\x99s true value",
#               "sentiment": 0
#             },
#             "10:40:50.873059": {
#               "text": "$LK buy buy buy !!",
#               "sentiment": 1
#             },
#             "10:40:50.873063": {
#               "text": "$LK @JohnBi0 @Escobar_Dollars \\xf0\\x9f\\x8d\\xba\\xf0\\x9f\\x8d\\xbb we did it boys",
#               "sentiment": 1
#             },
#             "10:40:50.873068": {
#               "text": "$LK 2500 shares now!",
#               "sentiment": 0
#             },
#             "10:40:50.873072": {
#               "text": "$LK are ya lucking kidding me!!! $5 incoming today maybe higher!!!",
#               "sentiment": 1
#             },
#             "10:40:50.873077": {
#               "text": "$LK",
#               "sentiment": 1
#             },
#             "10:40:50.873082": {
#               "text": "$LK I gotin PM for a trade . But I\\xe2\\x80\\x99m trying to put a valuation on this until the fraud smoke clears. Any quick hits on why this took off this week?",
#               "sentiment": 0
#             },
#             "10:39:50.873086": {
#               "text": "$LK $3 is the new $2...the powers that be don\\xe2\\x80\\x99t want it under that.",
#               "sentiment": 1
#             },
#             "10:39:50.873091": {
#               "text": "$LK",
#               "sentiment": 1
#             },
#             "10:39:50.873095": {
#               "text": "$LK setting sell limits to $25 by end of month",
#               "sentiment": 1
#             },
#             "10:39:50.873100": {
#               "text": "$LK hope we remember we are not a $3 stock, let\\xe2\\x80\\x99s wait till $10 atleast",
#               "sentiment": 1
#             },
#             "10:39:50.873104": {
#               "text": "Bullish Trades: $AAL $NIO $LK $PRMW $DFEN \\nTrading Strategies: Long, Call Writing and Put Selling\\n\\n#StockToWatch #StockToTrade #StockMarket #Investing #StockTrading #StockNews",
#               "sentiment": 1
#             },
#             "10:39:50.873109": {
#               "text": "$LK \\nI think we are just getting started.",
#               "sentiment": 0
#             }
#           },
#           "sentiment": {
#             "bullish": 27,
#             "bearish": 0,
#             "neutral": 13
#           },
#           "trendingScore": 6.24678,
#           "trending": false,
#           "volume": 33890096,
#           "volumeChange": -18.03,
#           "watchlistCount": 30658,
#           "low": 2.7,
#           "high": 3.22,
#           "price": 3.21,
#           "change": 0.63,
#           "percentChange": 24.419
#         },
#         "11:07": {
#           "ratio": 0.2098828622139119,
#           "mktcap": 863231000.0,
#           "comments": {
#             "11:07:16.174833": {
#               "text": "$AAL $LK  \\xf0\\x9f\\x94\\xa5\\xf0\\x9f\\x94\\xa5\\xf0\\x9f\\x94\\xa5",
#               "sentiment": 1
#             },
#             "11:07:16.174887": {
#               "text": "$LK SHORTS AND BEARS!!! GET THIS:",
#               "sentiment": 1
#             },
#             "11:07:16.174897": {
#               "text": "$LK Sweet baby Jesus!",
#               "sentiment": 0
#             },
#             "11:07:16.174902": {
#               "text": "$LK Was not expecting this without news. wow.",
#               "sentiment": 0
#             },
#             "11:07:16.174907": {
#               "text": "$LK 700% call returns lol",
#               "sentiment": 1
#             },
#             "11:07:16.174912": {
#               "text": "$LK doubled my position, let\\xe2\\x80\\x99s make some money",
#               "sentiment": 1
#             },
#             "11:07:16.174916": {
#               "text": "$LK schwab says ER on 6/9 after close",
#               "sentiment": 0
#             },
#             "11:07:16.174921": {
#               "text": "$LK this isn\\xe2\\x80\\x99t a short squeeze (yet)....but this is how it starts!! Keep buying!!",
#               "sentiment": 1
#             },
#             "11:07:16.174925": {
#               "text": "$LK hahahaha great man",
#               "sentiment": 1
#             },
#             "11:07:16.174929": {
#               "text": "$LK do not sell for chicken shit, hold for huuuge upside, 27 plus by end of next week with blow out earnings, and executives announcement",
#               "sentiment": 1
#             },
#             "11:07:16.174933": {
#               "text": "$LK Average share cost of around 1.55, sold LK 2.50 calls for the 3 weeks. To the man who purchased my 2.50 calls this week, let\\'s go have a drink together. Lol.",
#               "sentiment": 0
#             },
#             "11:07:16.174938": {
#               "text": "$LK Ho Lee Chit!  Just called Walmart and told them daddy is coming to take that bicycle on lay away from last year. Daddy is paying cash!",
#               "sentiment": 1
#             },
#             "11:07:16.174942": {
#               "text": "$LK moon",
#               "sentiment": 1
#             },
#             "11:07:16.174947": {
#               "text": "$GNUS I bought that dip. I sold my other lottery winnings ($LK) and put them in this one\\xe2\\x9c\\xa8\\xf0\\x9f\\x8c\\x9f\\xf0\\x9f\\x91\\xbd",
#               "sentiment": 1
#             },
#             "11:07:16.174951": {
#               "text": "$LK $20",
#               "sentiment": 1
#             },
#             "11:06:16.174958": {
#               "text": "$LK I am all out guys. Good luck.",
#               "sentiment": 0
#             },
#             "11:06:16.174964": {
#               "text": "$LK I thought this atock was going to be delisted, sorry I\\'m late to the party lol",
#               "sentiment": 0
#             },
#             "11:06:16.174969": {
#               "text": "$LK Lunch slump and we are still flying. $5 EOD",
#               "sentiment": 0
#             },
#             "11:06:16.174974": {
#               "text": "$LK is there an earnings date confirmed? Why the run?",
#               "sentiment": 0
#             },
#             "11:06:16.174979": {
#               "text": "$LK someone from the company just needs to sneeze now for it to reach $10",
#               "sentiment": 1
#             },
#             "11:06:16.174984": {
#               "text": "$LK 3.48 New High: 0.01. Next resistance 3.49 from 5/20/2020",
#               "sentiment": 0
#             },
#             "11:06:16.174989": {
#               "text": "$LK hello LK. I missed you. People waking up to smell the coffee.",
#               "sentiment": 1
#             },
#             "11:06:16.174994": {
#               "text": "$LK \\xf0\\x9f\\xa4\\x91\\xf0\\x9f\\xa4\\x91\\xf0\\x9f\\xa4\\x91\\xf0\\x9f\\xa4\\x91",
#               "sentiment": 0
#             },
#             "11:06:16.174998": {
#               "text": "$LK dont say no one showed you they may have told you buy we showed u",
#               "sentiment": 0
#             },
#             "11:06:16.175003": {
#               "text": "$LK will beat my profit of  2000% $GNUS",
#               "sentiment": 1
#             },
#             "11:06:16.175008": {
#               "text": "$LK SHORTS:",
#               "sentiment": 1
#             },
#             "11:06:16.175013": {
#               "text": "$LK Right.... see you all at 5.\\n\\xf0\\x9f\\xa4\\x91\\xf0\\x9f\\xa4\\x91\\xf0\\x9f\\xa4\\x91\\xf0\\x9f\\xa4\\x91",
#               "sentiment": 0
#             },
#             "11:06:16.175017": {
#               "text": "$LK Commie caffeine...",
#               "sentiment": 0
#             },
#             "11:06:16.175022": {
#               "text": "$LK not hard to lock in over 40% gains on this one, too much momentum to sell right now.",
#               "sentiment": 1
#             },
#             "11:06:16.175027": {
#               "text": "$LK \\xe2\\x98\\x95\\xe2\\x98\\x95\\xe2\\x98\\x95\\xe2\\x98\\x95\\xf0\\x9f\\x98\\x9d\\xf0\\x9f\\x8d\\xbe\\xf0\\x9f\\x8d\\xbe\\xf0\\x9f\\x8d\\xbe\\xf0\\x9f\\x8d\\xbe\\xf0\\x9f\\x8d\\xbe\\xf0\\x9f\\x8d\\xbe",
#               "sentiment": 0
#             },
#             "11:06:16.175032": {
#               "text": "$CAN  buy the dip! $LK $MARK",
#               "sentiment": 1
#             },
#             "11:06:16.175037": {
#               "text": "$LK man only have 1000 shares... @2.10 this will go back to the 50s the Chinese government is behind this garbage",
#               "sentiment": 1
#             },
#             "11:06:16.175041": {
#               "text": "$LK just sold my LK at 3.40. Bought it at 2.04 \\xf0\\x9f\\x9a\\x80 make that money guys!",
#               "sentiment": 1
#             },
#             "11:05:16.175047": {
#               "text": "$LK how many winners lol 5 today an 1 loss lol weeeeee",
#               "sentiment": 1
#             },
#             "11:05:16.175059": {
#               "text": "$LK 12 is coming",
#               "sentiment": 1
#             },
#             "11:05:16.175072": {
#               "text": "$LK lovin it....",
#               "sentiment": 1
#             },
#             "11:05:16.175084": {
#               "text": "$LK @GoldwomanSachs  so how\\xe2\\x80\\x99d shorting LK work our for ya ;)",
#               "sentiment": 0
#             },
#             "11:05:16.175090": {
#               "text": "$LK shorts are getting destroyed lmao. More they cover, higher we jump",
#               "sentiment": 0
#             },
#             "11:05:16.175095": {
#               "text": "$LK sold 1100 shares prematurely! Smh",
#               "sentiment": 1
#             }
#           },
#           "sentiment": {
#             "bullish": 23,
#             "bearish": 0,
#             "neutral": 16
#           },
#           "trendingScore": 7.0928,
#           "trending": false,
#           "volume": 43550359,
#           "relativeVolume": 9677857.555555556,
#           "volumeChange": -18.03,
#           "watchlistCount": 30740,
#           "low": 2.7,
#           "high": 3.5,
#           "price": 3.465,
#           "change": 0.885,
#           "percentChange": 34.302
#         },
#         "11:23": {
#           "relativeRatio": 0.0005188314707196421,
#           "ratio": 0.002853573088958032,
#           "mktcap": 98415000000.0,
#           "comments": {
#             "11:21:04.962759": {
#               "text": "$LOW 135 is a realistic next level but we are at all time ighs so I suspect traders are reluctant to jump in right now but the revenue is unavoidable \\xe2\\x80\\xa6 this is a great value stock ... it will go up period...",
#               "sentiment": 1
#             },
#             "11:12:04.962795": {
#               "text": "$LOW where we thinking the next run up is possibly going?",
#               "sentiment": 0
#             }
#           },
#           "sentiment": {
#             "bullish": 1,
#             "bearish": 0,
#             "neutral": 1
#           },
#           "trendingScore": -0.858749,
#           "trending": false,
#           "volume": 1959822,
#           "relativeVolume": 356331.2727272727,
#           "volumeChange": -20.48,
#           "watchlistCount": 11190,
#           "low": 130.2,
#           "high": 131.87,
#           "price": 130.37,
#           "change": -2.47,
#           "percentChange": -1.859
#         },
#         "11:24": {
#           "relativeRatio": 0.045748193432161854,
#           "ratio": 0.2516150638768902,
#           "mktcap": 817665000.0,
#           "comments": {
#             "11:21:09.690195": {
#               "text": "$LOW 135 is a realistic next level but we are at all time ighs so I suspect traders are reluctant to jump in right now but the revenue is unavoidable \\xe2\\x80\\xa6 this is a great value stock ... it will go up period...",
#               "sentiment": 1
#             },
#             "11:12:09.690266": {
#               "text": "$LOW where we thinking the next run up is possibly going?",
#               "sentiment": 0
#             }
#           },
#           "sentiment": {
#             "bullish": 1,
#             "bearish": 0,
#             "neutral": 1
#           },
#           "trendingScore": -0.858749,
#           "trending": false,
#           "volume": 1970419,
#           "relativeVolume": 358258.0,
#           "volumeChange": -20.48,
#           "watchlistCount": 11190,
#           "low": 130.2,
#           "high": 131.87,
#           "price": 130.39,
#           "change": -2.45,
#           "percentChange": -1.844
#         }
#       }
#     }
#   }
# }
