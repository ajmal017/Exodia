# %%
from yahoofinancials import YahooFinancials

ticker = 'AAPL'
yahoo_financials = YahooFinancials(ticker)

#balance_sheet_data_qt = yahoo_financials.get_financial_stmts('quarterly', 'balance')
#income_statement_data_qt = yahoo_financials.get_financial_stmts('quarterly', 'income')
#all_statement_data_qt =  yahoo_financials.get_financial_stmts('quarterly', ['income', 'cash', 'balance'])
#apple_earnings_data = yahoo_financials.get_stock_earnings_data()
#apple_net_income = yahoo_financials.get_net_income()
historical_stock_prices = yahoo_financials.get_historical_price_data('2008-09-15', '2020-05-15', 'weekly')

# %%
income_statement_data_qt = yahoo_financials.get_financial_stmts('quarterly', 'income')

# %%
income_statement_data_qt
# Out:
# {'incomeStatementHistoryQuarterly': {'TSLA': None}}

# %%
ticker = 'AAPL'
yahoo_financials = YahooFinancials(ticker)
divs = yahoo_financials.get_daily_dividend_data('2020-01-01', '2020-05-15')

# %%
print(yahoo_financials.get_key_statistics_data())
# Out:
# {'AAPL': None}

# %%
historical_stock_prices = yahoo_financials.get_historical_price_data('2020-01-01', '2020-05-15', 'daily')
historical_stock_prices
# Out:
# {'TSLA': {'eventsData': {},
#   'firstTradeDate': {'formatted_date': '2010-06-29', 'date': 1277818200},
#   'currency': 'USD',
#   'instrumentType': 'EQUITY',
#   'timeZone': {'gmtOffset': -14400},
#   'prices': [{'date': 1577975400,
#     'high': 430.70001220703125,
#     'low': 421.7099914550781,
#     'open': 424.5,
#     'close': 430.260009765625,
#     'volume': 9532100,
#     'adjclose': 430.260009765625,
#     'formatted_date': '2020-01-02'},
#    {'date': 1578061800,
#     'high': 454.0,
#     'low': 436.9200134277344,
#     'open': 440.5,
#     'close': 443.010009765625,
#     'volume': 17778500,
#     'adjclose': 443.010009765625,
#     'formatted_date': '2020-01-03'},
#    {'date': 1578321000,
#     'high': 451.55999755859375,
#     'low': 440.0,
#     'open': 440.4700012207031,
#     'close': 451.5400085449219,
#     'volume': 10133000,
#     'adjclose': 451.5400085449219,
#     'formatted_date': '2020-01-06'},
#    {'date': 1578407400,
#     'high': 471.6300048828125,
# ...

# %%
import requests

# %%
headers = {'Accept-Encoding': 'identity'}
url = 'https://financialmodelingprep.com/api/v3/financial-growth/AAPL?period=quarter&apikey=demo'
r = requests.get(url, headers=headers)

# %%
import json

# %%
r.json()
# Out:
# [{'symbol': 'AAPL',
#   'date': '2020-03-28',
#   'revenueGrowth': -0.36491357997800017,
#   'grossProfitGrowth': -0.36479541130703924,
#   'ebitgrowth': -0.49732097461770114,
#   'operatingIncomeGrowth': -0.49732097461770114,
#   'netIncomeGrowth': -0.4941086526353661,
#   'epsgrowth': -0.48611111111111116,
#   'epsdilutedGrowth': -0.48496993987975956,
#   'weightedAverageSharesGrowth': -0.006221914184242951,
#   'weightedAverageSharesDilutedGrowth': -0.0056022937167927835,
#   'dividendsperShareGrowth': -0.04037003896381279,
#   'operatingCashFlowGrowth': -0.5638025953598113,
#   'freeCashFlowGrowth': -0.59667710936675,
#   'tenYRevenueGrowthPerShare': -0.5875832358527281,
#   'fiveYRevenueGrowthPerShare': 0.3330458769849872,
#   'threeYRevenueGrowthPerShare': 0.32217210659414675,
#   'tenYOperatingCFGrowthPerShare': -0.6612944908434484,
#   'fiveYOperatingCFGrowthPerShare': -0.07489265644842691,
#   'threeYOperatingCFGrowthPerShare': 0.2748166897729436,
# ...
