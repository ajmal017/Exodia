# %%
from stocklive import Stock
from commentssentiment import CommentSentiment
from commentEMA import GenerateEMA
from newsIEXcloud import NewsIEX

# %%
import schedule
import time

# %%
def function(tickerList):
    now = str(datetime.datetime.now())
    nowDate = now.split(' ')[0]
    nowMin = now.split(' ')[1]
    
    n = NewsIEX()
    for tick in tickerList:
        n.getNews(tick,2)
    
    while int(nowMin[0:2]) < 20:
        for tim in range(6):
            print(f'Done {tim}. Time: {nowMin}')
            for tick in tickerList:
                #2.0 seconds for new stocks 
                Stock(tick).run()
            time.sleep(5*60-(0.3*len(tickerList)))
                
        for tick in tickerList:
            cs = CommentSentiment(tick,'newest')
            cs.saveStocktwits()
            cs.saveYahoo()
            
        now = str(datetime.datetime.now())
        nowDate = now.split(' ')[0]
        nowMin = now.split(' ')[1]
        
    print('\n\nDONE FOR THE DAY :)')
    schedule.every().day.at("08:00").do(run(tickerList),'It is 08:00.\n')
    while True:
        schedule.run_pending()
        time.sleep(60)

        
def run(tickerList):
    now = str(datetime.datetime.now())
    nowDate = now.split(' ')[0]
    nowMin = now.split(' ')[1]
    
    if int(nowMin[0:2]) < 8 or int(nowMin[0:2]) > 20:
        schedule.every().day.at("08:00").do(function(tickerList),'It is 08:00.\n')
        while True:
            schedule.run_pending()
            time.sleep(60)
    else:
        function(tickerList)
        
        

    #cs.parseStocktwitsComments('HEXO')
    #cs.parseYahooComments('HEXO')
    
    #ema = GenerateEMA()
    #ema.genEMA('HEXO',15,'yahoo')
    
    #AdjData = ema.getEMAdata('HEXO',15,'yahoo','adj')

# %%
tickerList = ['HEXO','VXRT','INO']
run(tickerList)
# Out:
# No text... using summary
# Delta: 13
# Done 2 days.
# No text... using summary
# Delta: 1
# Done 2 days.
# Less than 30 news articles.
# 1 done.
# 2 done.
# 3 done.
# 4 done.
# 5 done.
# 6 done.
# 7 done.
# 8 done.
# 9 done.
# 10 done.
# 11 done.
# No text... using summary
# 12 done.
# 13 done.
# 14 done.
# 15 done.
# 16 done.
# 17 done.
# 18 done.
# 19 done.
# 20 done.
# 21 done.
# 22 done.
# 23 done.
# 24 done.
# 25 done.
# 26 done.
# 27 done.
# No text... using summary
# 28 done.
# 29 done.
# 30 done.
# Delta: 18
# Delta: 2
# Done 2 days.
# Done 0. Time: 16:08:45.547625
# Done Live.
# Done Live.
# Done Live.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-126-70ddaf73b363> in <module>
#       1 tickerList = ['HEXO','VXRT','INO']
# ----> 2 run(tickerList)
#
# <ipython-input-125-099411dab03b> in run(tickerList)
#      43             time.sleep(60)
#      44     else:
# ---> 45         function(tickerList)
#      46
#      47
#
# <ipython-input-125-099411dab03b> in function(tickerList)
#      14                 #2.0 seconds for new stocks
#      15                 Stock(tick).run()
# ---> 16             time.sleep(5*60-(0.3*len(tickerList)))
#      17
#      18         for tick in tickerList:
#
# KeyboardInterrupt:

# %%
import pyEX as p

# %%
secret = 'sk_fae174660924464996b77d14209a973b'
public = 'pk_2f3691af11ad4df583c95f2a4d89d44a'
p.Client(api_token=secret, version='v1', api_limit=5)

# %%
news = p.news(count=(30), symbol='TSLA', token=secret, version='v1')

# %%
news
# Out:
# [{'datetime': 1594154880000,
#   'headline': 'Tesla’s stock is forming a bubble and new buyers should buckle-up for a crash',
#   'source': 'MarketWatch',
#   'url': 'https://cloud.iexapis.com/v1/news/article/29526a85-8bf8-42c8-87a6-15b0a5fe0818',
#   'summary': 'Tesla bulls are running but what goes up must come down, writes Mark Hulbert.',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/29526a85-8bf8-42c8-87a6-15b0a5fe0818',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1594153810000,
#   'headline': "4 Companies You Won't Believe Have A Smaller Market Cap Than Tesla",
#   'source': 'Benzinga',
#   'url': 'https://cloud.iexapis.com/v1/news/article/4f11afb9-d142-4e05-9bf5-b8da5ccc5aac',
#   'summary': "As Tesla Inc (NASDAQ: TSLA ) continues its meteoric rise, its swelling market cap has pushed it far passed the bounds of other automakers. As S&P 500 inclusion looks increasingly likely, Tesla is being valued more and more like a tech stock. As of July 7, Tesla sports a market cap of $257.6 billion. In fact, here are four companies Tesla recently passed in market cap value. Disney: When it comes to entertainment, not many are better than Walt Disney Co (NYSE: DIS ). But if you've ever driven in a Tesla, you'll know it's one of the most fun things you can buy. On top of the driving experience, a Tesla car also offers entertainment options such as karaoke, video games and even … Full story available on Benzinga.com",
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/4f11afb9-d142-4e05-9bf5-b8da5ccc5aac',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1594153746000,
#   'headline': 'Tesla’s overexcited fans and Musk’s reckless behavior',
#   'source': 'ValueWalk',
#   'url': 'https://cloud.iexapis.com/v1/news/article/c79a8fc5-f532-4625-a36a-71bf3c603b05',
#   'summary': 'Whintey Tilson’s email to investors discussing an update on Tesla Inc (NASDAQ:TSLA); Elon Musk’s reckless and immature behavior; Tesla’s overexcited fans should cool down a little; markets bombed, investors carried on. Q2 2020 hedge fund letters, conferences and more An Update On Tesla, Elon Musk’s Reckless And Immature Behavior 1) With yesterday’s 13.5% jump, Tesla’s […] The post Tesla’s overexcited fans and Musk’s reckless behavior appeared first on ValueWalk .',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/c79a8fc5-f532-4625-a36a-71bf3c603b05',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1594152195000,
#   'headline': 'BMW wants customers to pay a subscription fee to use features the car already has installed, like a heated steering wheel or adaptive cruise control',
#   'source': 'Business Insider',
#   'url': 'https://cloud.iexapis.com/v1/news/article/d567f073-1534-404d-bd2a-4e630e3a1790',
#   'summary': "In July, BMW will roll out a sweeping software update that includes digital personalization and on-demand functions. The automaker envisions a future where people will subscribe to existing features on their cars, such as a heated steering wheel or adaptive cruise control. The software will be compatible with BMWs with the automaker's latest Operating System 7, as well as the 2021 BMW 5 Series. Visit Business Insider's homepage for more stories . In July, BMW plans to launch a comprehensive software update on compatible cars that includes digital personalization and on-demand functions. The way it works, the automaker explained via a press release , is that BMW will provide the car's necessary hardware and software during assembly so that, later on, it can be activated according to the buyer's preference. BMW envisions a situation where, for example, if one customer wanted a feature that wasn't requested when they bought the car, it can be added afterward. And if that car came into new ownership with someone else, that new owner could also activate the features that they want.",
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/d567f073-1534-404d-bd2a-4e630e3a1790',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1594152061000,
#   'headline': 'Gold Spikes To 9-Year High, Bonds Bid As Stocks Skid',
#   'source': 'Zero Hedge',
#   'url': 'https://cloud.iexapis.com/v1/news/article/8c9f6f20-a520-4421-90dd-c952d652c20a',
#   'summary': "Gold Spikes To 9-Year High, Bonds Bid As Stocks Skid Tyler Durden Tue, 07/07/2020 - 16:01 Lost in the headlines about Amazon or Tesla or Nasdaq or whatever the latest Robinhood-er is chasing higher today, is the fact that gold prices continue to rise, with futures topping $1800 once again… (some chaotic swings recently) And spot prices back to their highest since Sept 2011... Source: Bloomberg And at the same time, so-called 'Safe Haven' from the virus have screamed higher at or near record bubble valuations... Source: Bloomberg As Bloomberg's Michael Regan notes, the trailing price-to earnings ratio of the S&P 500 Information Technology Index is about one decent rally away from cracking the 30 level, while the same ratio for consumer-discretionary stocks is fast approaching 40, in large part thanks to a record rally in Amazon.com Inc. With rising virus cases threatening to stymie the reopenings of various state economies and uncertainty over future stimulus packages, July is setting up to be a month of serious headline risk that could put to the test the Federal Reserve’s magic spell on the market, especially the most richly valued sectors .",
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/8c9f6f20-a520-4421-90dd-c952d652c20a',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1594151400000,
#   'headline': 'Another SEC Embarrassment: Elon Musk Actually Made $57 Million From His 2018 "Funding Secured" Settlement',
#   'source': 'Zero Hedge',
#   'url': 'https://cloud.iexapis.com/v1/news/article/60af3d44-8548-4dee-8869-e893e7a35a3b',
#   'summary': 'Another SEC Embarrassment: Elon Musk Actually Made $57 Million From His 2018 "Funding Secured" Settlement Tyler Durden Tue, 07/07/2020 - 15:50 As if taunting the SEC and potentially suggesting the regulator fellate you while your totally normal stock price trading drives your share price to all time record highs wasn\'t enough to register on the hubris scale… ...the pro-Tesla lot over at electrek decided to take it one step further on Tuesday and remind readers that not only does Musk not appear to care whatsoever about his required Twitter-sitter, but also that Musk actually made $50 million as a result of his 2018 settlement with the securities regulators. The blog notes that back in 2018, when the SEC sued Musk for the unconscionable act of faking an $80 billion buyout for his company, the regulator levied fines of $20 million onto both Tesla and Musk. Musk bought $20 million in stock from Tesla, seemingly to avoid the company having to pay the fine and with Musk winding up with ~71,000 shares in the process.',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/60af3d44-8548-4dee-8869-e893e7a35a3b',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1594145280000,
#   'headline': 'Rooftop Solar Rivals Take On Tesla',
#   'source': 'The Wall Street Journal',
#   'url': 'https://cloud.iexapis.com/v1/news/article/707bee22-0872-43a5-96aa-23d45636a2c6',
#   'summary': 'The combination of Sunrun and Vivint Solar forms a company that would overtake Tesla’s residential solar business in scale.',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/707bee22-0872-43a5-96aa-23d45636a2c6',
#   'lang': 'en',
#   'hasPaywall': True},
#  {'datetime': 1594143865000,
#   'headline': 'Why Tesla’s Financial Success Is Critical To The Future Of CleanTech — Part 2',
#   'source': 'CleanTechnica',
#   'url': 'https://cloud.iexapis.com/v1/news/article/ab85c261-1ceb-4592-97e1-8cbf17f87349',
#   'summary': "If you're starting here, a few notes to catch up: At the end of Part 1, I had been super interested in the possibilities and technology between both solar panels and electric vehicles, but it was clear these were impossibly expensive products that weren't intended for frugal people like me to ever own",
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/ab85c261-1ceb-4592-97e1-8cbf17f87349',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1594142837000,
#   'headline': 'Sunrun’s $3.2 billion Vivint Solar bid challenges Tesla’s energy ambitions',
#   'source': 'TechCrunch',
#   'url': 'https://cloud.iexapis.com/v1/news/article/c181377e-c4b0-4204-8a0a-7185fa4dd920',
#   'summary': 'Tesla’s 2014 acquisition of SolarCity turned the electric vehicle manufacturer into the undisputed largest player in residential solar, but that lead has steadily eroded as its major competitor, Sunrun, surged ahead with more aggressive plans. Now with the $3.2 billion dollar acquisition of the residential solar installation company, Vivint Solar, Sunrun looks to solidify its […]',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/c181377e-c4b0-4204-8a0a-7185fa4dd920',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1594141804000,
#   'headline': 'Pourquoi le constructeur automobile Tesla vend-il des shorts rouges en satin «S3XY» ?',
#   'source': 'Ouest-France',
#   'url': 'https://cloud.iexapis.com/v1/news/article/d82533a1-22e1-404d-a275-4742613bfb0b',
#   'summary': 'La nouvelle pour le moins surprenante a été annoncée par le milliardaire et patron de Tesla Elon Musk sur Twitter le 5 juillet : le constructeur de voitures électriques vend désormais des shorts rouges en satin sur son site internet.Portant l’inscription « S3XY » au dos en référence à différents…',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/d82533a1-22e1-404d-a275-4742613bfb0b',
#   'lang': 'fr',
#   'hasPaywall': False},
#  {'datetime': 1594137963000,
#   'headline': 'Stocks making the biggest moves midday: Novavax, Shake Shack, Tesla, Apple & more',
#   'source': 'CNBC',
#   'url': 'https://cloud.iexapis.com/v1/news/article/c0e7d249-f2a5-49b6-8de3-5e847b4f8c92',
#   'summary': 'These are the stocks posting the largest moves in midday trading.',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/c0e7d249-f2a5-49b6-8de3-5e847b4f8c92',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1594136053000,
#   'headline': 'Strong Tesla Deliveries Confirm That TSLA Stock is On its Way to $2,000',
#   'source': 'InvestorPlace',
#   'url': 'https://cloud.iexapis.com/v1/news/article/72e60513-c934-4312-a24a-05f432ef81db',
#   'summary': 'Valuation is a slight problem for TSLA stock in the near-term, but nothing to worry about in the big picture.',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/72e60513-c934-4312-a24a-05f432ef81db',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1594135295000,
#   'headline': 'JPMorgan boosts its Tesla price target on the strength of delivery data — but still expects the stock to fall 79% over the next year (TSLA)',
#   'source': 'Business Insider',
#   'url': 'https://cloud.iexapis.com/v1/news/article/a5385a89-e077-494b-adf8-f7d0d4e25e78',
#   'summary': 'Despite Tesla\'s meteoric rise in 2020, one analyst is sticking to his call that shares are set to fall 79% from current levels. In a note published on Monday, JPMorgan raised its price target on Tesla by $20 to $295 on strength in its second-quarter delivery numbers, but reiterated its underweight position. The firm said that if Tesla reports better-than-expected second-quarter earnings, it will likely be driven by "lumpy ZEV credit sales or the release of deferred revenue associated with autonomous driving features." JPMorgan\'s note is the opposite of a bullish one published by JMP Securities on Monday, which detailed how Tesla could hit $100 billion in revenue by 2025. Visit Business Insider\'s homepage for more stories . Tesla\'s meteoric rise in 2020 hasn\'t turned all skeptics into full-on believers, but the company is making progress. In a note published on Monday, JPMorgan raised its price target by $20 to $295 due to better-than-expected second quarter delivery data. Tesla said it delivered 90,650 vehicles in the quarter, nearly 60% higher than JPMorgan\'s estimate of 57,000.',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/a5385a89-e077-494b-adf8-f7d0d4e25e78',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1594134000000,
#   'headline': 'Tesla’s Short Shorts Are a Bit Like its Cars',
#   'source': 'The Wall Street Journal',
#   'url': 'https://cloud.iexapis.com/v1/news/article/7d5a7ba2-9d5c-478d-9271-f4be633036ad',
#   'summary': 'Elon Musk poked some fun at short sellers with an offer that critics can chuckle about too. Tesla’s limited-edition $69.420 short shorts are already sold out.',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/7d5a7ba2-9d5c-478d-9271-f4be633036ad',
#   'lang': 'en',
#   'hasPaywall': True},
#  {'datetime': 1594130517000,
#   'headline': "Behind Tesla's Mindblowing Rally: A Flood Of Daytrading Robinhooders",
#   'source': 'Zero Hedge',
#   'url': 'https://cloud.iexapis.com/v1/news/article/5e3034b7-0aef-452f-80bf-072ebea23de7',
#   'summary': "Behind Tesla's Mindblowing Rally: A Flood Of Daytrading Robinhooders Tyler Durden Tue, 07/07/2020 - 10:01 The tremendous Tesla rally continued this morning when the stock surged another $50 in early trading, adding another $9BN in value or roughly the market cap of Halliburton, on absolutely no news. In fact over the past week TSLA is now up 50% on absolutely no news. The early ramp pushed TSLA market cap to a record $265 billion, making it the same size as Home Depot and, as noted yesterday, bigger than Intel, Netflix, Walt Disney, AT&T, Bank of America and almost all other S&P 500 companies. So what is behind this ramp? Why the usual retail investor flood of course: according to RobinTrack TSLA - which is already the 12th most popular stock on Robinhood - was the most aggressively bought stock on the retail-heavy exchange in the past 24 hours… ... as retail investors just can't get enough.",
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/5e3034b7-0aef-452f-80bf-072ebea23de7',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1594130414000,
#   'headline': 'Tesla oder BMW?',
#   'source': 'BORSE ONLINE',
#   'url': 'https://cloud.iexapis.com/v1/news/article/80319587-0003-4ae9-a12d-f4b00dc82866',
#   'summary': 'Eine meiner zentralen Erwartungen hat sich bisher nicht erfüllt. Während "Wachstumswerte" wie Amazon oder Tesla gnadenlos weiter nach oben getrieben werden ("weil solchen Unternehmen ja bekanntlich die Zukunft gehört"), werden traditionelle Industrieaktien weiter als Kellerkinder der Börse gehandelt. Von Peter E. Huber',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/80319587-0003-4ae9-a12d-f4b00dc82866',
#   'lang': 'de',
#   'hasPaywall': False},
#  {'datetime': 1594128302000,
#   'headline': 'What Are Stocks Smoking?',
#   'source': 'Zero Hedge',
#   'url': 'https://cloud.iexapis.com/v1/news/article/e8c23cb0-b009-4a55-9ef8-b43313f180c8',
#   'summary': 'What Are Stocks Smoking? Tyler Durden Tue, 07/07/2020 - 09:25 Authored by Bill Blain via MorningPorridge.com, “Pleased to meet you, hope you guess my name..” For the past few weeks I’ve been cautiously optimistic. The virus is bad, but the economic damage looks far less than feared. We’ve seen economies, companies, and employment fare far less badly that predicted. I’ve even gone as far as to recently declare myself bullish on recovery prospects….. But, after a month of upside economic surprises, I sense the mood is beginning to change. There is less talk of V shapes, and we are back to more discussion about inverted L-shapes stretching into 2021/22. Maybe its summer lethargy or the renewed outbreaks in the US? Or hangovers from the packed weekend pubs that is causing the negativity? Or, is just the realisation that although the pandemic has caused less damage than feared – it’s still caused massive damage! France thinks it’s had a great virus because its economy will only be 8% smaller! (And, on a relative basis, they might be right..!) Not that any re-assessment of recovery expectations seems to matter to stock markets!',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/e8c23cb0-b009-4a55-9ef8-b43313f180c8',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1594127634000,
#   'headline': 'Mystified Tesla bears on Wall Street admit there appears to be nothing that can stop the stock right now',
#   'source': 'CNBC',
#   'url': 'https://cloud.iexapis.com/v1/news/article/362d698f-13ba-4e29-a99f-592f6ed87100',
#   'summary': 'Barclays and Morgan Stanley are underweight Tesla, but both firms believe the stock can continue its record run — for now.',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/362d698f-13ba-4e29-a99f-592f6ed87100',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1594127543000,
#   'headline': 'Top Analyst Upgrades and Downgrades: Ambarella, Annaly, Cinedigm, Fortinet, Kinder Morgan, 3M, Nikola, Nvidia, Tesla, Uber, YETI and More',
#   'source': '24/7 Wall street',
#   'url': 'https://cloud.iexapis.com/v1/news/article/591c5395-b7d1-40d7-b605-07cd453b3ba7',
#   'summary': 'No summary available.',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/591c5395-b7d1-40d7-b605-07cd453b3ba7',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1594126683099,
#   'headline': 'Tesla Stock Bubble-The New Bitcoin?',
#   'source': 'Medium',
#   'url': 'https://cloud.iexapis.com/v1/news/article/db917784-e00d-4d88-ba65-cf3e550555dc',
#   'summary': 'Good sales number, signs of improving bottom line and a moderate recovery in oil price seemed to have lent support on the fundamentals for Tesla stock. But all these seem to be unable to account for…',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/db917784-e00d-4d88-ba65-cf3e550555dc',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1594126149000,
#   'headline': 'Electric car firm Tesla providing equipment for energy storage plant in Dorset',
#   'source': 'Bournemouth Echo',
#   'url': 'https://cloud.iexapis.com/v1/news/article/d0c3fee8-edef-4aeb-9d77-45282b89c6e7',
#   'summary': 'THE electric car pioneer Tesla is supplying the equipment and software for an energy storage plant in Dorset.',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/d0c3fee8-edef-4aeb-9d77-45282b89c6e7',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1594124264000,
#   'headline': 'Tesla’s market value surpasses Detroit Three',
#   'source': 'Report AZ',
#   'url': 'https://cloud.iexapis.com/v1/news/article/39d163cc-a418-4d5c-87c5-75e12d36167f',
#   'summary': 'Tesla has grown by an average of $14 billion on each of five trading days.',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/39d163cc-a418-4d5c-87c5-75e12d36167f',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1594122782000,
#   'headline': "Tesla pone a la venta pantalones 'cortos' para mofarse de los especuladores",
#   'source': 'Publico',
#   'url': 'https://cloud.iexapis.com/v1/news/article/0eb9bc9b-39bc-4ebc-8cb0-1da6c75f0984',
#   'summary': 'La última ocurrencia de Elon Musk ha pasado por mofarse de los inversores que apuestan contra Tesla, poniendo a la venta unos pantalones cortos a precio desorbitado que, de paso, es un juego de palabras en inglés.',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/0eb9bc9b-39bc-4ebc-8cb0-1da6c75f0984',
#   'lang': 'es',
#   'hasPaywall': False},
#  {'datetime': 1594121580000,
#   'headline': 'Tesla-Chef: Elon Musk verkauft jetzt Satin-Shorts – und stichelt gegen skeptische Anleger',
#   'source': 'Stern',
#   'url': 'https://cloud.iexapis.com/v1/news/article/4e62543f-8141-4a0f-be05-cb4e3723f6b9',
#   'summary': 'Rote Satin-Shorts mit goldenem Emblem standen für kurze Zeit im Shop des Elektroautobauers Tesla – und waren im Nu ausverkauft. Ob Elon Musk nachproduzieren lässt? Fraglich. Ihm ging es nur um einen Seitenhieb auf kritische Anleger.',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/4e62543f-8141-4a0f-be05-cb4e3723f6b9',
#   'lang': 'de',
#   'hasPaywall': False},
#  {'datetime': 1594119878000,
#   'headline': 'Los nuevos máximos de Amazon o Tesla confirman la bonanza tecnológica',
#   'source': 'Investing.com Spain',
#   'url': 'https://cloud.iexapis.com/v1/news/article/886022c2-f160-4588-86ba-83abb46e2067',
#   'summary': 'https://es.investing.com/news/stock-market-news/los-nuevos-maximos-de-amazon-o-tesla-confirman-la-bonanza-tecnologica-2016651',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/886022c2-f160-4588-86ba-83abb46e2067',
#   'lang': 'es',
#   'hasPaywall': False},
#  {'datetime': 1594118491000,
#   'headline': 'Geniale Rache des Tesla-Chef: Elon Musk verkauft jetzt rote Höschen',
#   'source': 'Finanzen100',
#   'url': 'https://cloud.iexapis.com/v1/news/article/a95a0ade-0e84-4786-be2c-f8c65074dba8',
#   'summary': 'Skandalös kurze Shorts in rotem Satin – die verkauft gerade, kein Witz, der Elektroautobauer Tesla. Chef Elon Musk scheint kein Spaß zu umständlich, um gegen die Leerverkäufer der Tesla-Aktie zu sticheln.',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/a95a0ade-0e84-4786-be2c-f8c65074dba8',
#   'lang': 'de',
#   'hasPaywall': False},
#  {'datetime': 1594115631000,
#   'headline': 'OOOF, pinch me! Jaguar trademark adds fuel to all-electric F-Type successor speculation',
#   'source': 'The Next Web',
#   'url': 'https://cloud.iexapis.com/v1/news/article/f354f69b-20b4-4abe-8e18-b7ae56d51b73',
#   'summary': 'Jaguar’s all-electric i-Pace is proving quite popular at the moment, even famed car designer Henrik Fisker drives one, but let’s be honest, it doesn’t get our motor running in the way the F-Type does. But lucky for us, Jaguar could have an electric sports car on the way. According to a filing made in the last few months, spotted by Autocar, the British automaker is attempting to trademark the name “Jaguar EV-Type,” suggesting that an all-electric sports car could be on the horizon. [Read: ‘Cold-hearted’ Tesla threatened to close its dealerships without telling employees first] Jaguar could have used names… This story continues at The Next Web',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/f354f69b-20b4-4abe-8e18-b7ae56d51b73',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1594113446000,
#   'headline': 'Musk mocks Tesla short-sellers by selling red satin short shorts',
#   'source': 'Russia Today',
#   'url': 'https://cloud.iexapis.com/v1/news/article/75cd23bb-ac44-4fdb-901e-56869d212ed2',
#   'summary': 'Tesla’s website briefly crashed this week as CEO Elon Musk launched the sale of red satin shorts, lampooning investors who are betting against the electric carmaker. Read Full Article at RT.com',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/75cd23bb-ac44-4fdb-901e-56869d212ed2',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1594110600000,
#   'headline': 'U.S. Solar-Energy Company Sunrun to Buy Rival Vivint in All-Stock Deal',
#   'source': 'The Wall Street Journal',
#   'url': 'https://cloud.iexapis.com/v1/news/article/74cdba53-f4aa-4529-906c-a6990a899610',
#   'summary': 'Sunrun, which overtook Tesla to become the U.S.’s top installer of residential-solar systems, agreed to buy Blackstone-backed Vivint in all-stock deal valued at about $3.2 billion including debt.',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/74cdba53-f4aa-4529-906c-a6990a899610',
#   'lang': 'en',
#   'hasPaywall': True},
#  {'datetime': 1594107782000,
#   'headline': 'Elon Musk verkauft provokanten Gegenstand, Website sofort down',
#   'source': 'KURIER Medienhaus',
#   'url': 'https://cloud.iexapis.com/v1/news/article/b3470c4b-695f-49b2-b779-30f2a6813950',
#   'summary': 'Mit dem Angebot der "Tesla Short Shorts" macht sich Musk über sogenannte Short Seller lustig. Der für seine Provokationen bekannte Tesla-Gründer Elon Musk hat mit dem Verkauf von Satin-Shorts gegen skeptische Anleger gestichelt. Der US-Elektroautohersteller nahm am Sonntag auf seiner Website rote Shorts mit goldfarbenem Tesla-Logo und der Aufschrift S3XY - für die Modelle S, 3, X und Y - ins Sortiment. Wegen vieler Anfragen brach die Webseite zusammen, die Shorts waren schnell ausverkauft. Elon Musk: Ungewöhnliche Antwort an Kritiker Mit dem Angebot der "Tesla Short Shorts" macht sich Musk über skeptische Anleger lustig: Sogenannte Short Seller setzen mit Leerverkäufen auf fallende Aktienkurse und wollen so Gewinne erzielen. Viele Anleger halten Tesla für überbewertet und erwarten für die Zukunft sinkende Aktienkurse. APA/AFP/EVA HAMBACH Allerdings hält der Aufschwung von Tesla an, obwohl der Konzern nach wie vor viel weniger Autos verkauft als die Konkurrenz. Vergangene Woche stieg Tesla zum wertvollsten Autokonzern der Welt auf.',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/b3470c4b-695f-49b2-b779-30f2a6813950',
#   'lang': 'de',
#   'hasPaywall': False}]
